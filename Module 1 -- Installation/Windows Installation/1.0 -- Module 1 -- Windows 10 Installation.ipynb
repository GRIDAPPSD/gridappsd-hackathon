# %% [markdown]
# # Module 1: Installation & Runtime

# %% [markdown]
# This module contains detailed installation instructions and runtime environment tips for GridAPPS-D and its dependencies.

# %% [markdown]
# ![windows_10.png](attachment:windows_10.png)

# %% [markdown]
# ## IMPORTANT!!
#
# GridAPPS-D is internally a very powerful and complicated platform. It has several prerequsite software packages that must be installed in the correct sequence, inlcuding WSL, Ubuntu, and Docker. Failure to install the packages in the correct sequnce of steps will lead to a wide range of software errors which can very time-consuming to diagnose and correct.

# %% [markdown]
# ![instruction%20manual-2.png](attachment:instruction%20manual-2.png)

# %% [markdown]
# ### There are several known installation issues related to corporate VPNs and proxy servers. It is recommended to disconnect from your company / laboratory VPN. Additional support is listed at the end of this tutorial

# %% [markdown]
# ---

# %% [markdown]
# # Windows Installation Steps
#
# Click on the colored box to start a lesson. Each lesson opens in a new browser window
#
# * [Step 1: Create a virtual machine and install docker](1.1%20--%20Lesson%201.1%20--%20Virtual%20Machine%20%26%20Docker%20Setup.ipynb)
#
# * [Step 2: Install the GridAPPS-D Platform](1.2%20--%20Lesson%201.2%20--%20Installing%20GridAPPS-D.ipynb)
#
# * [Step 3: Launch the GridAPPS-D Platform](1.3%20--%20Lesson%201.3%20--%20Running%20GridAPPS-D.ipynb)
#
# * [Step 4: Install Python library and training notebooks](1.4%20--%20Lesson%201.4%20--%20Installing%20Python%20Tutorials.ipynb)
#
# * [Step 5: Familiarize yourself with the Viz tools](1.5%20--%20Lesson%201.5%20--%20Using%20GridAPPS-D%20Viz.ipynb)
#
# * [Step 6: Review common docker shortcuts](1.6%20--%20Lesson%201.6%20--%20Docker%20Shortcuts.ipynb)

# %% [markdown]
# ![module_1.png](attachment:module_1.png)

# %% [markdown]
# [![lesson%201.1.png](attachment:lesson%201.1.png)](1.1%20--%20Lesson%201.1%20--%20Virtual%20Machine%20%26%20Docker%20Setup.ipynb)

# %% [markdown]
# [![lesson%201.2.png](attachment:lesson%201.2.png)](1.2%20--%20Lesson%201.2%20--%20Installing%20GridAPPS-D.ipynb)

# %% [markdown]
# [![lesson%201.3.png](attachment:lesson%201.3.png)](1.3%20--%20Lesson%201.3%20--%20Running%20GridAPPS-D.ipynb)

# %% [markdown]
# [![lesson%201.4.png](attachment:lesson%201.4.png)](1.4%20--%20Lesson%201.4%20--%20Installing%20Python%20Tutorials.ipynb)

# %% [markdown]
# [![lesson%201.5.png](attachment:lesson%201.5.png)](1.5%20--%20Lesson%201.5%20--%20Using%20GridAPPS-D%20Viz.ipynb)

# %% [markdown]
# [![lesson%201.6.png](attachment:lesson%201.6.png)](1.6%20--%20Lesson%201.6%20--%20Docker%20Shortcuts.ipynb)

# %% [markdown]
# ## System Requirements
#
# * __OS:__
#     * Windows 10, Version 2004 or higher, with Build 19041 or higher
# * __RAM:__
#     * 8GB (_absolute minimum_ for 13 and 123 node models, _may encounter memory overload during installation_ );
#     * 16GB (preferred for small models, minimum for 8500/9500 node models);
#     * 32GB (recommended for application development)
# * __Disk Space:__
#     * 15GB required for installation
#
# __Note:__ The download size is quite large, so it is recommended to use a fiber or ethernet interent connection, rathered than a metered hotspot to avoid excessive data usage charges.

# %% [markdown]
# ---
