# %% [markdown]
# # Lesson 2.2:
# # Using the PowerGrid Models API with SPARQL Queries
#
# This tutorial focuses on how to make generic queries of the PowerGrid Models API to obtain names, mRIDs, measurements, and control setting objects modeled in CIM XML for common power system equipment used in GridAPPS-D.
#
# The lesson reviews the format used for making generic SPARQL queries and then presents an extensive catalog of cut-and-paste code blocks for the most common queries.
#
# __Learning Objectives:__
#
# At the end of the tutorial, the user should be able to use the PowerGrid Models API to
#
# *
# *
# *
#
# ## Getting Started
#
# Before running any of the sample routines in this tutorial, it is first necessary to start the GridAPPS-D Platform and establish a connection to this notebook so that we can start passing calls to the API.

# %% [markdown]
# _Open the Ubuntu terminal and start the GridAPPS-D Platform if it is not running already:_
#
# `cd gridappsd-docker`
#
# ~/gridappsd-docker$ `./run.sh -t develop`
#
# _Once containers are running,_
#
# gridappsd@[container]:/gridappsd$ `./run-gridappsd.sh`

# %%
# Establish connection to GridAPPS-D Platform:
from gridappsd import GridAPPSD
gapps = GridAPPSD("('localhost', 61613)", username='system', password='manager')
model_mrid = "_49AD8E07-3BF9-A4E2-CB8F-C3722F837B62" # IEEE 13 Node used for all example queries

# %% [markdown]
# ---
# # Table of Contents
#
# * [1. Structure of Generic SPARQL Queries](#1.-Structure-of-Generic-SPARQL-Queries)
# * [2. Making SPARQL Queries using the GridAPPSD-Python API](#2.-Making-SPARQL-Queries-using-the-GridAPPSD-Python-API)
# * [3. Making SPARQL Queries using the STOMP Client](#3.-Making-SPARQL-Queries-using-the-STOMP-Client)
# * [4. Making SPARQL Queries using the Blazegraph Workbench](#4.-Making-SPARQL-Queries-using-the-Blazegraph-Workbench)
# * [5. Catalog of Common SPARQL Queries for CIM Objects](#5.-Catalog-of-Common-SPARQL-Queries-for-CIM-Objects)

# %% [markdown]
# # 1. Structure of Generic SPARQL Queries
#
# The format of SPARQL queries was discussed in detail previously in [Lesson 1.7]().

# %% [markdown]
# # 2. Making SPARQL Queries using the GridAPPSD-Python API

# %% [markdown]
# ---
# # 3. Making SPARQL Queries using the Blazegraph Workbench
#
# Open the [Blazegraph Workbench on localhost:8889/bigdata](http://localhost:8889/bigdata/#query)
#
#
#
# In the query input window, it is possible to directly copy and paste quere

# %% [markdown]
# ---
# # 4. Making SPARQL Queries using the STOMP Client
#
#
# Open the [GridAPPS-D Viz on localhost:8080](http://localhost:8080/) and log in.
#
# Open the menu in the top left corner and select `Stomp Client`
#
# ![image.png](attachment:image.png)
#
# Change the topic to the Powergrid Model API topic: `goss.gridappsd.process.request.data.powergridmodel`
#
# Enter the SPARQL query wrapped as a JSON string, like this, and click `Send request`

# %% [markdown]
# ```
# {
#         "requestType": "QUERY",
#         "resultFormat": "JSON",
#         "queryString": "select ?feeder_name ?subregion_name ?region_name WHERE {?line r:type c:Feeder.?line c:IdentifiedObject.name  ?feeder_name.?line c:Feeder.NormalEnergizingSubstation ?substation.?substation r:type c:Substation.?substation c:Substation.Region ?subregion.?subregion  c:IdentifiedObject.name  ?subregion_name .?subregion c:SubGeographicalRegion.Region  ?region . ?region   c:IdentifiedObject.name  ?region_name}"
# }
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The PowerGrid Model API response will be displayed in the dialogue box below.

# %% [markdown]
# ---
# # 5. Catalog of Common SPARQL Queries for CIM Objects
#
# The sections below present common power system equipment and measurement objects. The

# %% [markdown]
# ## 5.1. Queries for all feeder models and core objects

# %% [markdown]
# ### List all the feeders, with substations and regions

# %%
query = """
# list all the feeders, with substations and regions - DistFeeder
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?feeder ?fid ?station ?sid ?subregion ?sgrid ?region ?rgnid WHERE {
 # ?s r:type c:Feeder.
 # ?s c:IdentifiedObject.name ?feeder.
 # ?s c:IdentifiedObject.mRID ?fid.
 # ?s c:Feeder.NormalEnergizingSubstation ?sub.
 # ?sub c:IdentifiedObject.name ?station.
 # ?sub c:IdentifiedObject.mRID ?sid.
 # ?sub c:Substation.Region ?sgr.
 # ?sgr c:IdentifiedObject.name ?subregion.
 # ?sgr c:IdentifiedObject.mRID ?sgrid.
 # ?sgr c:SubGeographicalRegion.Region ?rgn.
 # ?rgn c:IdentifiedObject.name ?region.
 # ?rgn c:IdentifiedObject.mRID ?rgnid.
}
ORDER by ?station ?feeder
"""

# %%
# Preview API call output for the query
gapps.query_data(query)
# Out:
# {'data': {'head': {'vars': ['feeder',
#     'fid',
#     'station',
#     'sid',
#     'subregion',
#     'sgrid',
#     'region',
#     'rgnid']},
#   'results': {'bindings': [{'feeder': {'type': 'literal', 'value': 'ieee123'},
#      'fid': {'type': 'literal',
#       'value': '_C1C3E687-6FFD-C753-582B-632A27E28507'},
#      'station': {'type': 'literal', 'value': 'IEEE123'},
#      'sid': {'type': 'literal',
#       'value': '_FE44B314-385E-C2BF-3983-3A10C6060022'},
#      'subregion': {'type': 'literal', 'value': 'Medium'},
#      'sgrid': {'type': 'literal',
#       'value': '_1CD7D2EE-3C91-3248-5662-A43EFEFAC224'},
#      'region': {'type': 'literal', 'value': 'IEEE'},
#      'rgnid': {'type': 'literal',
#       'value': '_73C512BD-7249-4F50-50DA-D93849B89C43'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee123pv'},
#      'fid': {'type': 'literal',
#       'value': '_E407CBB6-8C8D-9BC9-589C-AB83FBF0826D'},
#      'station': {'type': 'literal', 'value': 'IEEE123'},
#      'sid': {'type': 'literal',
#       'value': '_FE44B314-385E-C2BF-3983-3A10C6060022'},
#      'subregion': {'type': 'literal', 'value': 'Medium'},
#      'sgrid': {'type': 'literal',
#       'value': '_1CD7D2EE-3C91-3248-5662-A43EFEFAC224'},
#      'region': {'type': 'literal', 'value': 'IEEE'},
#      'rgnid': {'type': 'literal',
#       'value': '_73C512BD-7249-4F50-50DA-D93849B89C43'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'fid': {'type': 'literal',
#       'value': '_49AD8E07-3BF9-A4E2-CB8F-C3722F837B62'},
#      'station': {'type': 'literal', 'value': 'IEEE13'},
#      'sid': {'type': 'literal',
#       'value': '_6C62C905-6FC7-653D-9F1E-1340F974A587'},
#      'subregion': {'type': 'literal', 'value': 'Small'},
#      'sgrid': {'type': 'literal',
#       'value': '_ABEB635F-729D-24BF-B8A4-E2EF268D8B9E'},
#      'region': {'type': 'literal', 'value': 'IEEE'},
#      'rgnid': {'type': 'literal',
#       'value': '_73C512BD-7249-4F50-50DA-D93849B89C43'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodecktassets'},
#      'fid': {'type': 'literal',
#       'value': '_5B816B93-7A5F-B64C-8460-47C17D6E4B0F'},
#      'station': {'type': 'literal', 'value': 'IEEE13'},
#      'sid': {'type': 'literal',
#       'value': '_6C62C905-6FC7-653D-9F1E-1340F974A587'},
#      'subregion': {'type': 'literal', 'value': 'Small'},
#      'sgrid': {'type': 'literal',
#       'value': '_ABEB635F-729D-24BF-B8A4-E2EF268D8B9E'},
#      'region': {'type': 'literal', 'value': 'IEEE'},
#      'rgnid': {'type': 'literal',
#       'value': '_73C512BD-7249-4F50-50DA-D93849B89C43'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee8500'},
#      'fid': {'type': 'literal',
#       'value': '_4F76A5F9-271D-9EB8-5E31-AA362D86F2C3'},
#      'station': {'type': 'literal', 'value': 'IEEE8500'},
#      'sid': {'type': 'literal',
#       'value': '_F1E8E479-5FA0-4BFF-8173-B375D25B0AA2'},
#      'subregion': {'type': 'literal', 'value': 'Large'},
#      'sgrid': {'type': 'literal',
#       'value': '_A1170111-942A-6ABD-D325-C64886DC4D7D'},
#      'region': {'type': 'literal', 'value': 'IEEE'},
#      'rgnid': {'type': 'literal',
#       'value': '_73C512BD-7249-4F50-50DA-D93849B89C43'}},
#     {'feeder': {'type': 'literal', 'value': 'j1'},
#      'fid': {'type': 'literal',
#       'value': '_67AB291F-DCCD-31B7-B499-338206B9828F'},
#      'station': {'type': 'literal', 'value': 'J1'},
#      'sid': {'type': 'literal',
#       'value': '_A3C31EE7-4EE6-A167-87C7-915B1C6E97F0'},
#      'subregion': {'type': 'literal', 'value': 'DPV'},
#      'sgrid': {'type': 'literal',
#       'value': '_096FDFB8-2692-D811-F483-553D578399F2'},
#      'region': {'type': 'literal', 'value': 'EPRI'},
#      'rgnid': {'type': 'literal',
#       'value': '_9A1E61E4-5CF1-982B-C7EF-0918D26645C7'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee123transactive'},
#      'fid': {'type': 'literal',
#       'value': '_503D6E20-F499-4CC7-8051-971E23D0BF79'},
#      'station': {'type': 'literal', 'value': 'PNNL'},
#      'sid': {'type': 'literal',
#       'value': '_A4C079AE-FE2B-4D11-969E-1268AFC562E9'},
#      'subregion': {'type': 'literal', 'value': 'Medium'},
#      'sgrid': {'type': 'literal',
#       'value': '_2BBFD370-B30F-4EC5-B7AE-6873921C8C7C'},
#      'region': {'type': 'literal', 'value': 'IEEE'},
#      'rgnid': {'type': 'literal',
#       'value': '_24BA911D-65D5-4769-9A30-4178B2DFA203'}},
#     {'feeder': {'type': 'literal', 'value': 'test9500new'},
#      'fid': {'type': 'literal',
#       'value': '_AAE94E4A-2465-6F5E-37B1-3E72183A4E44'},
#      'station': {'type': 'literal', 'value': 'ThreeSubs'},
#      'sid': {'type': 'literal',
#       'value': '_40485321-9B2C-1B8C-EC33-39D2F7948163'},
#      'subregion': {'type': 'literal', 'value': 'Large'},
#      'sgrid': {'type': 'literal',
#       'value': '_A1170111-942A-6ABD-D325-C64886DC4D7D'},
#      'region': {'type': 'literal', 'value': 'IEEE'},
#      'rgnid': {'type': 'literal',
#       'value': '_73C512BD-7249-4F50-50DA-D93849B89C43'}},
#     {'feeder': {'type': 'literal', 'value': 'acep_psil'},
#      'fid': {'type': 'literal',
#       'value': '_77966920-E1EC-EE8A-23EE-4EFD23B205BD'},
#      'station': {'type': 'literal', 'value': 'UAF'},
#      'sid': {'type': 'literal',
#       'value': '_22B12048-23DF-007B-9291-826A16DBCB21'},
#      'subregion': {'type': 'literal', 'value': 'Fairbanks'},
#      'sgrid': {'type': 'literal',
#       'value': '_2F8FC9BF-FF32-A197-D541-0A2529D04DF7'},
#      'region': {'type': 'literal', 'value': 'Alaska'},
#      'rgnid': {'type': 'literal',
#       'value': '_96465E7A-6EC3-ECCA-BC27-31B53F05C96E'}},
#     {'feeder': {'type': 'literal', 'value': 'sourceckt'},
#      'fid': {'type': 'literal',
#       'value': '_9CE150A8-8CC5-A0F9-B67E-BBD8C79D3095'},
#      'station': {'type': 'literal', 'value': 'sourceckt_Substation'},
#      'sid': {'type': 'literal',
#       'value': '_933D85C1-BE1C-4C05-D4DD-4B41D941C52C'},
#      'subregion': {'type': 'literal', 'value': 'Taxonomy'},
#      'sgrid': {'type': 'literal',
#       'value': '_656EE259-23FF-086E-1DC0-39CB9DC60A20'},
#      'region': {'type': 'literal', 'value': 'PNNL'},
#      'rgnid': {'type': 'literal',
#       'value': '_79C9D814-3CE0-DC11-534D-BDA1AF949810'}}]}},
#  'responseComplete': True,
#  'id': '1201965134'}

# %% [markdown]
# ## 2. Get all mRID values by class and name

# %%
query = """
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?type ?name ?id WHERE {
 # ?s c:IdentifiedObject.name ?name.
 # ?s c:IdentifiedObject.mRID ?id.
 # ?s r:type ?rawtype.
  bind(strafter(str(?rawtype),"#") as ?type)
}
ORDER by ?type ?name
"""

# %%
# Preview API call output
gapps.query_data(query)

# %% [markdown]
# # 1. Querying for Buses and Nodes

# %% [markdown]
# ## 1.1. List the bus name and xy coordinates
#
#
# Note: this query is the basis of qbus_template in InsertDER.py

# %%
query = """
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?bus ?seq ?locid ?x ?y WHERE { # ?cnid ?tid ?eqid
VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?cn c:ConnectivityNode.ConnectivityNodeContainer ?fdr.
 # ?trm c:Terminal.ConnectivityNode ?cn.
 # ?trm c:ACDCTerminal.sequenceNumber ?seq.
 # ?trm c:Terminal.ConductingEquipment ?eq.
 # ?eq c:PowerSystemResource.Location ?loc.
 # ?trm c:IdentifiedObject.mRID ?tid.
 # ?cn c:IdentifiedObject.mRID ?cnid.
 # ?cn c:IdentifiedObject.name ?bus.
 # ?eq c:IdentifiedObject.mRID ?eqid.
 # ?loc c:IdentifiedObject.mRID ?locid.
 # ?pt c:PositionPoint.Location ?loc.
 # caution - these next three triples make the query very slow, uncomment only if needed
 # ?pt c:PositionPoint.sequenceNumber ?seq.
 # ?pt c:PositionPoint.xPosition ?x.
 # ?pt c:PositionPoint.yPosition ?y
}
ORDER BY ?bus ?locid

""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)
# Out:
# {'data': {'head': {'vars': ['bus', 'seq', 'locid', 'x', 'y']},
#   'results': {'bindings': [{'bus': {'type': 'literal', 'value': '611'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_08866A9B-A318-4DA1-83FE-16EAD7927BA9'}},
#     {'bus': {'type': 'literal', 'value': '611'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_5A4B421C-35AA-45FA-B364-43236D22BCEE'}},
#     {'bus': {'type': 'literal', 'value': '611'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_5A4B421C-35AA-45FA-B364-43236D22BCEE'}},
#     {'bus': {'type': 'literal', 'value': '611'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_FC53E92B-32FE-4DE3-B77D-BE8D4364B5F8'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_3A63B621-3FA6-4805-96F9-DD57A7F88ACF'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_3A63B621-3FA6-4805-96F9-DD57A7F88ACF'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_3D3B02A5-E9D5-45F0-9506-22B098EDA261'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_3D3B02A5-E9D5-45F0-9506-22B098EDA261'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_5DEC8E61-DFE8-4506-BD5A-5CBCBB6532EE'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_5DEC8E61-DFE8-4506-BD5A-5CBCBB6532EE'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_E85D20C3-84EA-43F6-9D31-5239FAB00019'}},
#     {'bus': {'type': 'literal', 'value': '632'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_E85D20C3-84EA-43F6-9D31-5239FAB00019'}},
#     {'bus': {'type': 'literal', 'value': '633'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_3D3B02A5-E9D5-45F0-9506-22B098EDA261'}},
#     {'bus': {'type': 'literal', 'value': '633'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_3D3B02A5-E9D5-45F0-9506-22B098EDA261'}},
#     {'bus': {'type': 'literal', 'value': '633'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_9702BD06-90C3-40B5-9311-47FA1C2A9811'}},
#     {'bus': {'type': 'literal', 'value': '633'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_9702BD06-90C3-40B5-9311-47FA1C2A9811'}},
#     {'bus': {'type': 'literal', 'value': '634'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_34199075-733E-4B94-9EC2-50DD84C1D8D5'}},
#     {'bus': {'type': 'literal', 'value': '634'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_6D30F773-D772-465C-9A4C-41624B283C2C'}},
#     {'bus': {'type': 'literal', 'value': '634'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_6D30F773-D772-465C-9A4C-41624B283C2C'}},
#     {'bus': {'type': 'literal', 'value': '634'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_83FA529E-9B45-4022-BD00-3E9867EFD55D'}},
#     {'bus': {'type': 'literal', 'value': '634'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_952BE5EC-68EC-46CA-9290-6BCD9BE00A0C'}},
#     {'bus': {'type': 'literal', 'value': '634'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_E17D6B98-44E7-4746-8605-BF75E6AC6277'}},
#     {'bus': {'type': 'literal', 'value': '634'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_FC973B3E-2AC2-4C61-804D-6CF40FFF3CC0'}},
#     {'bus': {'type': 'literal', 'value': '645'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_7DB84AEE-89EE-4C77-BEFA-E58CB10FADA1'}},
#     {'bus': {'type': 'literal', 'value': '645'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_89C21411-D107-454A-93B0-0905893DD27D'}},
#     {'bus': {'type': 'literal', 'value': '645'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_89C21411-D107-454A-93B0-0905893DD27D'}},
#     {'bus': {'type': 'literal', 'value': '645'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_E85D20C3-84EA-43F6-9D31-5239FAB00019'}},
#     {'bus': {'type': 'literal', 'value': '645'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_E85D20C3-84EA-43F6-9D31-5239FAB00019'}},
#     {'bus': {'type': 'literal', 'value': '646'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_89C21411-D107-454A-93B0-0905893DD27D'}},
#     {'bus': {'type': 'literal', 'value': '646'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_89C21411-D107-454A-93B0-0905893DD27D'}},
#     {'bus': {'type': 'literal', 'value': '646'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_9E735173-F2E5-408C-8279-54ED0D3BBDD1'}},
#     {'bus': {'type': 'literal', 'value': '650'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_085BBE1F-FF95-4260-A9D2-8D2F1A8EA9A3'}},
#     {'bus': {'type': 'literal', 'value': '650'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_085BBE1F-FF95-4260-A9D2-8D2F1A8EA9A3'}},
#     {'bus': {'type': 'literal', 'value': '650'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': '650'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': '650'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': '650z'},
#      'seq': {'type': 'literal', 'value': '3'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': '650z'},
#      'seq': {'type': 'literal', 'value': '3'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': '650z'},
#      'seq': {'type': 'literal', 'value': '3'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': '652'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_8515F6BA-7A0F-424B-AF83-F41950CE8FD6'}},
#     {'bus': {'type': 'literal', 'value': '652'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_CF03D366-44AC-4088-B698-D42F4E39D8C4'}},
#     {'bus': {'type': 'literal', 'value': '652'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_CF03D366-44AC-4088-B698-D42F4E39D8C4'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_216C1943-900F-4939-92FE-A3A4817363D8'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_216C1943-900F-4939-92FE-A3A4817363D8'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_BE71BF98-CD79-4A6D-804B-6729A6EB8020'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_BE71BF98-CD79-4A6D-804B-6729A6EB8020'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_D6E129D9-385E-46D5-B6D3-81ECB2D2BE17'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_F75309B4-3341-4B2F-B55A-3B93C934CC3F'}},
#     {'bus': {'type': 'literal', 'value': '670'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_FAD8DFE7-AB35-4DC5-B9EC-63F15CE2BE92'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_58246081-FEDB-4DE7-8173-C408CFE3803E'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_58246081-FEDB-4DE7-8173-C408CFE3803E'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_6E6EDB91-07A8-46E9-BDC5-733EAB0552F7'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_6E6EDB91-07A8-46E9-BDC5-733EAB0552F7'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_7522F97F-CF73-4B94-BD26-B5E4E7B3AC04'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_7522F97F-CF73-4B94-BD26-B5E4E7B3AC04'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_A1B4F004-D48C-43A3-8DE8-E22CF6FB28AD'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_BE71BF98-CD79-4A6D-804B-6729A6EB8020'}},
#     {'bus': {'type': 'literal', 'value': '671'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_BE71BF98-CD79-4A6D-804B-6729A6EB8020'}},
#     {'bus': {'type': 'literal', 'value': '675'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_5F4F5E06-9447-448B-8DE4-F4E22AA34576'}},
#     {'bus': {'type': 'literal', 'value': '675'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_62A249A4-4BF9-42BB-9E0A-06D132216D9A'}},
#     {'bus': {'type': 'literal', 'value': '675'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_68234FFD-2C36-4D95-9E00-74CEB6ED0995'}},
#     {'bus': {'type': 'literal', 'value': '675'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_EA84B9C8-A620-487E-89E7-A55984E71968'}},
#     {'bus': {'type': 'literal', 'value': '675'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_F302E764-FCD7-41AF-903E-42A4F0045EEF'}},
#     {'bus': {'type': 'literal', 'value': '675'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_F302E764-FCD7-41AF-903E-42A4F0045EEF'}},
#     {'bus': {'type': 'literal', 'value': '680'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_6E6EDB91-07A8-46E9-BDC5-733EAB0552F7'}},
#     {'bus': {'type': 'literal', 'value': '680'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_6E6EDB91-07A8-46E9-BDC5-733EAB0552F7'}},
#     {'bus': {'type': 'literal', 'value': '684'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_58246081-FEDB-4DE7-8173-C408CFE3803E'}},
#     {'bus': {'type': 'literal', 'value': '684'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_58246081-FEDB-4DE7-8173-C408CFE3803E'}},
#     {'bus': {'type': 'literal', 'value': '684'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_CF03D366-44AC-4088-B698-D42F4E39D8C4'}},
#     {'bus': {'type': 'literal', 'value': '684'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_CF03D366-44AC-4088-B698-D42F4E39D8C4'}},
#     {'bus': {'type': 'literal', 'value': '684'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_DC47C3ED-EF6A-4D32-916E-36D33DD338FC'}},
#     {'bus': {'type': 'literal', 'value': '684'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_DC47C3ED-EF6A-4D32-916E-36D33DD338FC'}},
#     {'bus': {'type': 'literal', 'value': '692'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_0A390CC2-AFE7-477C-8D42-63EE609F842B'}},
#     {'bus': {'type': 'literal', 'value': '692'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_7522F97F-CF73-4B94-BD26-B5E4E7B3AC04'}},
#     {'bus': {'type': 'literal', 'value': '692'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_7522F97F-CF73-4B94-BD26-B5E4E7B3AC04'}},
#     {'bus': {'type': 'literal', 'value': '692'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_F302E764-FCD7-41AF-903E-42A4F0045EEF'}},
#     {'bus': {'type': 'literal', 'value': '692'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_F302E764-FCD7-41AF-903E-42A4F0045EEF'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_085BBE1F-FF95-4260-A9D2-8D2F1A8EA9A3'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_085BBE1F-FF95-4260-A9D2-8D2F1A8EA9A3'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'brkr'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_0C4D68BF-AC73-45C8-B2BD-FF3BFBCD20E1'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_0F434724-42D6-4F82-855E-0BE55C717FF0'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '3'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '3'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '3'},
#      'locid': {'type': 'literal',
#       'value': '_AB09CC43-A30F-48C3-B55B-0558CE61C579'}},
#     {'bus': {'type': 'literal', 'value': 'house'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_EF80FC47-029B-401F-9E63-45BE7AB0530B'}},
#     {'bus': {'type': 'literal', 'value': 'mid'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_216C1943-900F-4939-92FE-A3A4817363D8'}},
#     {'bus': {'type': 'literal', 'value': 'mid'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_216C1943-900F-4939-92FE-A3A4817363D8'}},
#     {'bus': {'type': 'literal', 'value': 'mid'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_5DEC8E61-DFE8-4506-BD5A-5CBCBB6532EE'}},
#     {'bus': {'type': 'literal', 'value': 'mid'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_5DEC8E61-DFE8-4506-BD5A-5CBCBB6532EE'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_16F0DA5A-A603-45D1-B14B-DA3EFF209FD3'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_3A63B621-3FA6-4805-96F9-DD57A7F88ACF'}},
#     {'bus': {'type': 'literal', 'value': 'rg60'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_3A63B621-3FA6-4805-96F9-DD57A7F88ACF'}},
#     {'bus': {'type': 'literal', 'value': 'sourcebus'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_3818472D-6569-4901-849F-D5A68F6CDC24'}},
#     {'bus': {'type': 'literal', 'value': 'sourcebus'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': 'sourcebus'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': 'sourcebus'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_6CE06D43-8DE4-4C72-B059-F71EAE02DDDD'}},
#     {'bus': {'type': 'literal', 'value': 'tap'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_5A4B421C-35AA-45FA-B364-43236D22BCEE'}},
#     {'bus': {'type': 'literal', 'value': 'tap'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_5A4B421C-35AA-45FA-B364-43236D22BCEE'}},
#     {'bus': {'type': 'literal', 'value': 'tap'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_DC47C3ED-EF6A-4D32-916E-36D33DD338FC'}},
#     {'bus': {'type': 'literal', 'value': 'tap'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_DC47C3ED-EF6A-4D32-916E-36D33DD338FC'}},
#     {'bus': {'type': 'literal', 'value': 'xf1'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_6D30F773-D772-465C-9A4C-41624B283C2C'}},
#     {'bus': {'type': 'literal', 'value': 'xf1'},
#      'seq': {'type': 'literal', 'value': '1'},
#      'locid': {'type': 'literal',
#       'value': '_6D30F773-D772-465C-9A4C-41624B283C2C'}},
#     {'bus': {'type': 'literal', 'value': 'xf1'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_9702BD06-90C3-40B5-9311-47FA1C2A9811'}},
#     {'bus': {'type': 'literal', 'value': 'xf1'},
#      'seq': {'type': 'literal', 'value': '2'},
#      'locid': {'type': 'literal',
#       'value': '_9702BD06-90C3-40B5-9311-47FA1C2A9811'}}]}},
#  'responseComplete': True,
#  'id': '1647463145'}

# %% [markdown]
# ## List all the connectivity nodes by feeder

# %%
query = """
# list all the connectivity nodes by feeder
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?feeder ?name WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?s c:ConnectivityNode.ConnectivityNodeContainer ?fdr.
 # ?s r:type c:ConnectivityNode.
 # ?s c:IdentifiedObject.name ?name.
 # ?fdr c:IdentifiedObject.name ?feeder.
}
ORDER by ?feeder ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %% [markdown]
# ## List all the connectivity nodes by feeder, with voltage limits

# %%
query = """
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?feeder ?bus ?cnid ?val ?dur ?dir WHERE {
VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?s c:ConnectivityNode.ConnectivityNodeContainer ?fdr.
 # ?s r:type c:ConnectivityNode.
 # ?s c:IdentifiedObject.name ?bus.
 # ?s c:IdentifiedObject.mRID ?cnid.
 # ?fdr c:IdentifiedObject.name ?feeder.
 # ?s c:ConnectivityNode.OperationalLimitSet ?ols.
 # ?vlim c:OperationalLimit.OperationalLimitSet ?ols.
 # ?vlim r:type c:VoltageLimit.
 # ?vlim c:OperationalLimit.OperationalLimitType ?olt.
 # ?olt c:OperationalLimitType.acceptableDuration ?dur.
 # ?olt c:OperationalLimitType.direction ?rawdir.
  bind(strafter(str(?rawdir),"OperationalLimitDirectionKind.") as ?dir)
 # ?vlim c:VoltageLimit.value ?val.
}
ORDER by ?feeder ?bus ?val
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %% [markdown]
# ## 1.2. List all the connectivity node base voltages by feeder, for sensor service
# ```
# PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX c:  <http://iec.ch/TC57/CIM100#>
# SELECT DISTINCT ?feeder ?busname ?cnid ?nomv WHERE {
# # VALUES ?fdrid {"_49AD8E07-3BF9-A4E2-CB8F-C3722F837B62"}  # 13 bus
#  ?fdr c:IdentifiedObject.mRID ?fdrid.
#  ?bus c:ConnectivityNode.ConnectivityNodeContainer ?fdr.
#  ?bus r:type c:ConnectivityNode.
#  ?bus c:IdentifiedObject.name ?busname.
#  ?bus c:IdentifiedObject.mRID ?cnid.
#  ?fdr c:IdentifiedObject.name ?feeder.
#  ?trm c:Terminal.ConnectivityNode ?bus.
#  ?trm c:Terminal.ConductingEquipment ?ce.
#  ?ce  c:ConductingEquipment.BaseVoltage ?bv.
#  ?bv  c:BaseVoltage.nominalVoltage ?nomv.
# }
# ORDER by ?feeder ?busname ?nomv
# ```

# %% [markdown]
# ## List all the connectivity node base voltages by feeder, for visualization

# %%
query = """
# list all the connectivity node base voltages by feeder, for visualization
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT DISTINCT ?feeder ?busname ?nomv WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?bus c:ConnectivityNode.ConnectivityNodeContainer ?fdr.
 # ?bus r:type c:ConnectivityNode.
 # ?bus c:IdentifiedObject.name ?busname.
 # ?fdr c:IdentifiedObject.name ?feeder.
 # ?trm c:Terminal.ConnectivityNode ?bus.
 # ?trm c:Terminal.ConductingEquipment ?ce.
 # ?ce  c:ConductingEquipment.BaseVoltage ?bv.
 # ?bv  c:BaseVoltage.nominalVoltage ?nomv.
}
ORDER by ?feeder ?busname ?nomv
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)
# Out:
# {'data': {'head': {'vars': ['feeder', 'busname', 'nomv']},
#   'results': {'bindings': [{'feeder': {'type': 'literal',
#       'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '611'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '632'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '633'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '634'},
#      'nomv': {'type': 'literal', 'value': '480'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '645'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '646'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '650'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '652'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '670'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '671'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '675'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '680'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '684'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': '692'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': 'brkr'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': 'house'},
#      'nomv': {'type': 'literal', 'value': '208'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': 'mid'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': 'rg60'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': 'sourcebus'},
#      'nomv': {'type': 'literal', 'value': '115000'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': 'tap'},
#      'nomv': {'type': 'literal', 'value': '4160'}},
#     {'feeder': {'type': 'literal', 'value': 'ieee13nodeckt'},
#      'busname': {'type': 'literal', 'value': 'xf1'},
#      'nomv': {'type': 'literal', 'value': '4160'}}]}},
#  'responseComplete': True,
#  'id': '227669260'}

# %% [markdown]
# # Querying for Switching Equipment
#
# The sample queries below present the most commonly needed queries for power system model information related to switching objects.
#
# The models currently stored in GridAPPS-D only use the _LoadBreakSwitch_ object for switching objects, so queries for other classes of switching objects are commented out in the sample code blocks below.

# %% [markdown]
# ## Fuse, Breaker, Recloser, LoadBreakSwitch, Sectionaliser
#
# This query features several different types of distribution switches available within CIM XML. The models currently stored in GridAPPS-D only use the _LoadBreakSwitch_ object for switching objects, so the other queries are commented out in this sample code block.
#
# Note: the sectionalizer object will be supported in a future release.

# %%
query = """
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?name ?basev ?open ?continuous ?breaking ?fdrid (group_concat(distinct ?bus;separator="\n") as ?buses) (group_concat(distinct ?phs;separator="\n") as ?phases) WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?s r:type c:Sectionaliser.
 # ?s r:type c:Disconnector.
 # ?s r:type c:Fuse.
 # ?s r:type c:Recloser.
 # ?s r:type c:Breaker.
 # ?s r:type c:LoadBreakSwitch.
 # ?s c:Equipment.EquipmentContainer ?fdr.
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?s c:IdentifiedObject.name ?name.
 # ?s c:ConductingEquipment.BaseVoltage ?bv.
 # ?bv c:BaseVoltage.nominalVoltage ?basev.
 # ?s c:Switch.normalOpen ?open.
 # ?s c:Switch.ratedCurrent ?continuous.
 OPTIONAL {?s c:ProtectedSwitch.breakingCapacity ?breaking.}
 # ?t c:Terminal.ConductingEquipment ?s.
 # ?t c:Terminal.ConnectivityNode ?cn. 
 # ?cn c:IdentifiedObject.name ?bus
 OPTIONAL {?swp c:SwitchPhase.Switch ?s.
 # ?swp c:SwitchPhase.phaseSide1 ?phsraw.
   bind(strafter(str(?phsraw),"SinglePhaseKind.") as ?phs) }
}
GROUP BY ?name ?basev ?open ?continuous ?breaking ?fdrid
ORDER BY ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)
# Out:
# {'error': {'message': 'org.apache.jena.query.QueryParseException: Lexical error at line 4, column 95.  Encountered: "\\n" (10), after : "\\""\n\tat org.apache.jena.sparql.lang.ParserSPARQL11.perform(ParserSPARQL11.java:109)\n\tat org.apache.jena.sparql.lang.ParserSPARQL11.parse$(ParserSPARQL11.java:52)\n\tat org.apache.jena.sparql.lang.SPARQLParser.parse(SPARQLParser.java:34)\n\tat org.apache.jena.query.QueryFactory.parse(QueryFactory.java:147)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:79)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:52)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:40)\n\tat gov.pnnl.goss.gridappsd.data.handlers.BlazegraphQueryHandler.query(BlazegraphQueryHandler.java:96)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerImpl.queryResultSet(BGPowergridModelDataManagerImpl.java:202)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerImpl.query(BGPowergridModelDataManagerImpl.java:177)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerHandlerImpl.handle(BGPowergridModelDataManagerHandlerImpl.java:32)\n\tat gov.pnnl.goss.gridappsd.data.DataManagerImpl.processDataRequest(DataManagerImpl.java:149)\n\tat gov.pnnl.goss.gridappsd.process.ProcessEvent.onMessage(ProcessEvent.java:229)\n\tat pnnl.goss.core.client.GossClient$1.run(GossClient.java:329)\n\tat java.lang.Thread.run(Thread.java:748)\n'},
#  'responseComplete': True,
#  'id': 'ec079289-fa0f-47e7-9847-8fdb2f285484'}

# %%
query = """
# Storage - DistStorage
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?name ?bus ?ratedS ?ratedU ?ipu ?ratedE ?storedE ?state ?p ?q ?id ?fdrid (group_concat(distinct ?phs;separator="\n") as ?phases) WHERE {
 # ?s r:type c:BatteryUnit.
 # ?s c:IdentifiedObject.name ?name.
 # ?pec c:PowerElectronicsConnection.PowerElectronicsUnit ?s.
# feeder selection options - if all commented out, query matches all feeders
#VALUES ?fdrid {"_C1C3E687-6FFD-C753-582B-632A27E28507"}  # 123 bus
#VALUES ?fdrid {"_49AD8E07-3BF9-A4E2-CB8F-C3722F837B62"}  # 13 bus
#VALUES ?fdrid {"_5B816B93-7A5F-B64C-8460-47C17D6E4B0F"}  # 13 bus assets
#VALUES ?fdrid {"_4F76A5F9-271D-9EB8-5E31-AA362D86F2C3"}  # 8500 node
#VALUES ?fdrid {"_67AB291F-DCCD-31B7-B499-338206B9828F"}  # J1
#VALUES ?fdrid {"_9CE150A8-8CC5-A0F9-B67E-BBD8C79D3095"}  # R2 12.47 3
 # ?pec c:Equipment.EquipmentContainer ?fdr.
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?pec c:PowerElectronicsConnection.ratedS ?ratedS.
 # ?pec c:PowerElectronicsConnection.ratedU ?ratedU.
 # ?pec c:PowerElectronicsConnection.maxIFault ?ipu.
 # ?s c:BatteryUnit.ratedE ?ratedE.
 # ?s c:BatteryUnit.storedE ?storedE.
 # ?s c:BatteryUnit.batteryState ?stateraw.
   bind(strafter(str(?stateraw),"BatteryState.") as ?state)
 # ?pec c:PowerElectronicsConnection.p ?p.
 # ?pec c:PowerElectronicsConnection.q ?q. 
 OPTIONAL {?pecp c:PowerElectronicsConnectionPhase.PowerElectronicsConnection ?pec.
 # ?pecp c:PowerElectronicsConnectionPhase.phase ?phsraw.
   bind(strafter(str(?phsraw),"SinglePhaseKind.") as ?phs) }
 bind(strafter(str(?s),"#_") as ?id).
 # ?t c:Terminal.ConductingEquipment ?pec.
 # ?t c:Terminal.ConnectivityNode ?cn. 
 # ?cn c:IdentifiedObject.name ?bus
}
GROUP by ?name ?bus ?ratedS ?ratedU ?ipu ?ratedE ?storedE ?state ?p ?q ?id ?fdrid
ORDER by ?name
"""

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)
# Out:
# {'error': {'message': 'org.apache.jena.query.QueryParseException: Lexical error at line 5, column 120.  Encountered: "\\n" (10), after : "\\""\n\tat org.apache.jena.sparql.lang.ParserSPARQL11.perform(ParserSPARQL11.java:109)\n\tat org.apache.jena.sparql.lang.ParserSPARQL11.parse$(ParserSPARQL11.java:52)\n\tat org.apache.jena.sparql.lang.SPARQLParser.parse(SPARQLParser.java:34)\n\tat org.apache.jena.query.QueryFactory.parse(QueryFactory.java:147)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:79)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:52)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:40)\n\tat gov.pnnl.goss.gridappsd.data.handlers.BlazegraphQueryHandler.query(BlazegraphQueryHandler.java:96)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerImpl.queryResultSet(BGPowergridModelDataManagerImpl.java:202)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerImpl.query(BGPowergridModelDataManagerImpl.java:177)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerHandlerImpl.handle(BGPowergridModelDataManagerHandlerImpl.java:32)\n\tat gov.pnnl.goss.gridappsd.data.DataManagerImpl.processDataRequest(DataManagerImpl.java:149)\n\tat gov.pnnl.goss.gridappsd.process.ProcessEvent.onMessage(ProcessEvent.java:229)\n\tat pnnl.goss.core.client.GossClient$1.run(GossClient.java:329)\n\tat java.lang.Thread.run(Thread.java:748)\n'},
#  'responseComplete': True,
#  'id': 'abc7b09a-68eb-448a-8dc0-ed1c8e3a662b'}

# %% [markdown]
# ## SynchronousMachine - DistSyncMachine

# %%
query = """
# SynchronousMachine - DistSyncMachine
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?name ?bus (group_concat(distinct ?phs;separator="\n") as ?phases) ?ratedS ?ratedU ?p ?q ?id ?fdrid WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?s r:type c:SynchronousMachine.
 # ?s c:IdentifiedObject.name ?name.
 # ?s c:Equipment.EquipmentContainer ?fdr.
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?s c:SynchronousMachine.ratedS ?ratedS.
 # ?s c:SynchronousMachine.ratedU ?ratedU.
 # ?s c:SynchronousMachine.p ?p.
 # ?s c:SynchronousMachine.q ?q. 
 bind(strafter(str(?s),"#_") as ?id).
 OPTIONAL {?smp c:SynchronousMachinePhase.SynchronousMachine ?s.
 # ?smp c:SynchronousMachinePhase.phase ?phsraw.
   bind(strafter(str(?phsraw),"SinglePhaseKind.") as ?phs) }
 # ?t c:Terminal.ConductingEquipment ?s.
 # ?t c:Terminal.ConnectivityNode ?cn. 
 # ?cn c:IdentifiedObject.name ?bus
}
GROUP by ?name ?bus ?ratedS ?ratedU ?p ?q ?id ?fdrid
ORDER by ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %%
query = """
# Solar - DistSolar
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?name ?bus ?ratedS ?ratedU ?ipu ?p ?q ?fdrid (group_concat(distinct ?phs;separator="\n") as ?phases) WHERE {
 # ?s r:type c:PhotovoltaicUnit.
 # ?s c:IdentifiedObject.name ?name.
 # ?pec c:PowerElectronicsConnection.PowerElectronicsUnit ?s.
# feeder selection options - if all commented out, query matches all feeders
#VALUES ?fdrid {"_C1C3E687-6FFD-C753-582B-632A27E28507"}  # 123 bus
#VALUES ?fdrid {"_49AD8E07-3BF9-A4E2-CB8F-C3722F837B62"}  # 13 bus
#VALUES ?fdrid {"_5B816B93-7A5F-B64C-8460-47C17D6E4B0F"}  # 13 bus assets
#VALUES ?fdrid {"_4F76A5F9-271D-9EB8-5E31-AA362D86F2C3"}  # 8500 node
#VALUES ?fdrid {"_67AB291F-DCCD-31B7-B499-338206B9828F"}  # J1
#VALUES ?fdrid {"_9CE150A8-8CC5-A0F9-B67E-BBD8C79D3095"}  # R2 12.47 3
 # ?pec c:Equipment.EquipmentContainer ?fdr.
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?pec c:PowerElectronicsConnection.ratedS ?ratedS.
 # ?pec c:PowerElectronicsConnection.ratedU ?ratedU.
 # ?pec c:PowerElectronicsConnection.maxIFault ?ipu.
 # ?pec c:PowerElectronicsConnection.p ?p.
 # ?pec c:PowerElectronicsConnection.q ?q.
 OPTIONAL {?pecp c:PowerElectronicsConnectionPhase.PowerElectronicsConnection ?pec.
 # ?pecp c:PowerElectronicsConnectionPhase.phase ?phsraw.
   bind(strafter(str(?phsraw),"SinglePhaseKind.") as ?phs) }
 # ?t c:Terminal.ConductingEquipment ?pec.
 # ?t c:Terminal.ConnectivityNode ?cn. 
 # ?cn c:IdentifiedObject.name ?bus
}
GROUP by ?name ?bus ?ratedS ?ratedU ?ipu ?p ?q ?fdrid
ORDER by ?name

"""

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)
# Out:
# {'error': {'message': 'org.apache.jena.query.QueryParseException: Lexical error at line 5, column 92.  Encountered: "\\n" (10), after : "\\""\n\tat org.apache.jena.sparql.lang.ParserSPARQL11.perform(ParserSPARQL11.java:109)\n\tat org.apache.jena.sparql.lang.ParserSPARQL11.parse$(ParserSPARQL11.java:52)\n\tat org.apache.jena.sparql.lang.SPARQLParser.parse(SPARQLParser.java:34)\n\tat org.apache.jena.query.QueryFactory.parse(QueryFactory.java:147)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:79)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:52)\n\tat org.apache.jena.query.QueryFactory.create(QueryFactory.java:40)\n\tat gov.pnnl.goss.gridappsd.data.handlers.BlazegraphQueryHandler.query(BlazegraphQueryHandler.java:96)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerImpl.queryResultSet(BGPowergridModelDataManagerImpl.java:202)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerImpl.query(BGPowergridModelDataManagerImpl.java:177)\n\tat gov.pnnl.goss.gridappsd.data.BGPowergridModelDataManagerHandlerImpl.handle(BGPowergridModelDataManagerHandlerImpl.java:32)\n\tat gov.pnnl.goss.gridappsd.data.DataManagerImpl.processDataRequest(DataManagerImpl.java:149)\n\tat gov.pnnl.goss.gridappsd.process.ProcessEvent.onMessage(ProcessEvent.java:229)\n\tat pnnl.goss.core.client.GossClient$1.run(GossClient.java:329)\n\tat java.lang.Thread.run(Thread.java:748)\n'},
#  'responseComplete': True,
#  'id': '26c40b81-566b-48d1-baba-ed2b0514247c'}

# %%
query = """
# list houses - DistHouse
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?fdrname ?name ?parent ?coolingSetpoint ?coolingSystem ?floorArea ?heatingSetpoint ?heatingSystem ?hvacPowerFactor ?numberOfStories ?thermalIntegrity ?id ?fdrid 
WHERE { 
   VALUES ?fdrid {"%s"}  # inserts model_mrid
   # ?h r:type c:House.
   # ?h c:IdentifiedObject.name ?name.
   # ?h c:IdentifiedObject.mRID ?id.
   # ?h c:House.floorArea ?floorArea.
   # ?h c:House.numberOfStories ?numberOfStories.
   OPTIONAL{?h c:House.coolingSetpoint ?coolingSetpoint.}
   OPTIONAL{?h c:House.heatingSetpoint ?heatingSetpoint.}
   OPTIONAL{?h c:House.hvacPowerFactor ?hvacPowerFactor.}
   # ?h c:House.coolingSystem ?coolingSystemRaw.
   	bind(strafter(str(?coolingSystemRaw),"HouseCooling.") as ?coolingSystem) 
   # ?h c:House.heatingSystem ?heatingSystemRaw.
   	bind(strafter(str(?heatingSystemRaw),"HouseHeating.") as ?heatingSystem)
   # ?h c:House.thermalIntegrity ?thermalIntegrityRaw.
   	bind(strafter(str(?thermalIntegrityRaw),"HouseThermalIntegrity.") as ?thermalIntegrity)
   # ?h c:House.EnergyConsumer ?econ.
   # ?econ c:IdentifiedObject.name ?parent.
   # ?fdr c:IdentifiedObject.mRID ?fdrid.
   # ?fdr c:IdentifiedObject.name ?fdrname.
   # ?econ c:Equipment.EquipmentContainer ?fdr.
} 
ORDER BY ?fdrname ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %% [markdown]
# # Querying for measurements

# %% [markdown]
# ## List all measurements, with buses and equipments

# %%
query = """
# list all measurements, with buses and equipments
PREFIX r: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c: <http://iec.ch/TC57/CIM100#>
SELECT ?class ?type ?name ?bus ?phases ?eqtype ?eqname ?eqid ?trmid ?id WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?eq c:Equipment.EquipmentContainer ?fdr.
 # ?fdr c:IdentifiedObject.mRID ?fdrid. 
{ ?s r:type c:Discrete. bind ("Discrete" as ?class)}
  UNION
{ ?s r:type c:Analog. bind ("Analog" as ?class)}
 # ?s c:IdentifiedObject.name ?name .
 # ?s c:IdentifiedObject.mRID ?id .
 # ?s c:Measurement.PowerSystemResource ?eq .
 # ?s c:Measurement.Terminal ?trm .
 # ?s c:Measurement.measurementType ?type .
 # ?trm c:IdentifiedObject.mRID ?trmid.
 # ?eq c:IdentifiedObject.mRID ?eqid.
 # ?eq c:IdentifiedObject.name ?eqname.
 # ?eq r:type ?typeraw.
  bind(strafter(str(?typeraw),"#") as ?eqtype)
 # ?trm c:Terminal.ConnectivityNode ?cn.
 # ?cn c:IdentifiedObject.name ?bus.
 # ?s c:Measurement.phases ?phsraw .
   {bind(strafter(str(?phsraw),"PhaseCode.") as ?phases)}
} 
ORDER BY ?class ?type ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %% [markdown]
# ## List measurement points for PowerTransformer with no tanks

# %%
query = """
# list measurement points for PowerTransformer with no tanks
PREFIX r: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c: <http://iec.ch/TC57/CIM100#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?name ?wnum ?bus ?eqid ?trmid WHERE { 
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?s c:Equipment.EquipmentContainer ?fdr.
 # ?fdr c:IdentifiedObject.mRID ?fdrid. 
 # ?s r:type c:PowerTransformer.
 # ?s c:IdentifiedObject.name ?name.
 # ?s c:IdentifiedObject.mRID ?eqid.
 # ?end c:PowerTransformerEnd.PowerTransformer ?s.
 # ?end c:TransformerEnd.Terminal ?trm.
 # ?end c:TransformerEnd.endNumber ?wnum.
 # ?trm c:IdentifiedObject.mRID ?trmid. 
 # ?trm c:Terminal.ConnectivityNode ?cn. 
 # ?cn c:IdentifiedObject.name ?bus.
}
ORDER BY ?name ?wnum
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %% [markdown]
# ## List measurement points for Breakers, Reclosers, LoadBreakSwitches in a selected feeder
#
# This query obtains

# %%
query = """
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?cimtype ?name ?bus1 ?bus2 ?id (group_concat(distinct ?phs;separator="") as ?phases) WHERE {
SELECT ?cimtype ?name ?bus1 ?bus2 ?phs ?id WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 VALUES ?cimraw {c:LoadBreakSwitch c:Recloser c:Breaker}
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?s r:type ?cimraw.
  bind(strafter(str(?cimraw),"#") as ?cimtype)
 # ?s c:Equipment.EquipmentContainer ?fdr.
 # ?s c:IdentifiedObject.name ?name.
 # ?s c:IdentifiedObject.mRID ?id.
 # ?t1 c:Terminal.ConductingEquipment ?s.
 # ?t1 c:ACDCTerminal.sequenceNumber "1".
 # ?t1 c:Terminal.ConnectivityNode ?cn1. 
 # ?cn1 c:IdentifiedObject.name ?bus1.
 # ?t2 c:Terminal.ConductingEquipment ?s.
 # ?t2 c:ACDCTerminal.sequenceNumber "2".
 # ?t2 c:Terminal.ConnectivityNode ?cn2. 
 # ?cn2 c:IdentifiedObject.name ?bus2
 OPTIONAL {?swp c:SwitchPhase.Switch ?s.
 # ?swp c:SwitchPhase.phaseSide1 ?phsraw.
   bind(strafter(str(?phsraw),"SinglePhaseKind.") as ?phs) }
 } ORDER BY ?name ?phs
}
GROUP BY ?cimtype ?name ?bus1 ?bus2 ?id
ORDER BY ?cimtype ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %% [markdown]
# ## List measurement points for PowerElectronicsConnection with BatteryUnit in a selected feeder

# %%
query = """
# list measurement points for PowerElectronicsConnection with BatteryUnit in a selected feeder
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?name ?uname ?bus ?id (group_concat(distinct ?phs;separator="") as ?phases) WHERE {
  SELECT ?name ?uname ?bus ?phs ?id WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?s r:type c:PowerElectronicsConnection.
 # ?s c:Equipment.EquipmentContainer ?fdr.
 # ?s c:IdentifiedObject.name ?name.
 # ?s c:IdentifiedObject.mRID ?id.
 # ?peu r:type c:BatteryUnit.
 # ?peu c:IdentifiedObject.name ?uname.
 # ?s c:PowerElectronicsConnection.PowerElectronicsUnit ?peu.
 # ?t1 c:Terminal.ConductingEquipment ?s.
 # ?t1 c:ACDCTerminal.sequenceNumber "1".
 # ?t1 c:Terminal.ConnectivityNode ?cn1. 
 # ?cn1 c:IdentifiedObject.name ?bus.
 OPTIONAL {?pep c:PowerElectronicsConnectionPhase.PowerElectronicsConnection ?s.
 # ?pep c:PowerElectronicsConnectionPhase.phase ?phsraw.
 bind(strafter(str(?phsraw),"SinglePhaseKind.") as ?phs) }
 } ORDER BY ?name ?phs
}
GROUP BY ?name ?uname ?bus ?id
ORDER BY ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)

# %% [markdown]
# ## List measurement points for ACLineSegments in a selected feeder

# %%
query = """
# list measurement points for ACLineSegments in a selected feeder
PREFIX r:  <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX c:  <http://iec.ch/TC57/CIM100#>
SELECT ?name ?bus1 ?bus2 ?id (group_concat(distinct ?phs;separator="") as ?phases) WHERE {
  SELECT ?name ?bus1 ?bus2 ?phs ?id WHERE {
 VALUES ?fdrid {"%s"}  # inserts model_mrid
 # ?fdr c:IdentifiedObject.mRID ?fdrid.
 # ?s r:type c:ACLineSegment.
 # ?s c:Equipment.EquipmentContainer ?fdr.
 # ?s c:IdentifiedObject.name ?name.
 # ?s c:IdentifiedObject.mRID ?id.
 # ?t1 c:Terminal.ConductingEquipment ?s.
 # ?t1 c:ACDCTerminal.sequenceNumber "1".
 # ?t1 c:Terminal.ConnectivityNode ?cn1. 
 # ?cn1 c:IdentifiedObject.name ?bus1.
 # ?t2 c:Terminal.ConductingEquipment ?s.
 # ?t2 c:ACDCTerminal.sequenceNumber "2".
 # ?t2 c:Terminal.ConnectivityNode ?cn2. 
 # ?cn2 c:IdentifiedObject.name ?bus2
 OPTIONAL {?acp c:ACLineSegmentPhase.ACLineSegment ?s.
 # ?acp c:ACLineSegmentPhase.phase ?phsraw.
 bind(strafter(str(?phsraw),"SinglePhaseKind.") as ?phs) }
 } ORDER BY ?name ?phs
}
GROUP BY ?name ?bus1 ?bus2 ?id
ORDER BY ?name
""" % model_mrid

# %%
# Preview API call output for the query on the IEEE 13 node model
gapps.query_data(query)
