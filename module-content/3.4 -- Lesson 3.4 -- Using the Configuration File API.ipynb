# %% [markdown]
# # Lesson 2.4:
# # Configuration File API
#
# This tutorial introduces the Configuration File API and how it can be used to generate and export custom GridLab-D and OpenDSS versions of the power system models stored in the Blazegraph database.
#
# __Learning Objectives:__
#
# At the end of the tutorial, the user should be able to use the Configuration File API to
#
# * Generate a custom GridLab-D simulation file
# * Export a GridLab-D base GLM file
# * Export a list of GridLab-D measurements
# * Generate a customer OpenDSS power system model
# * Export a list of OpenDSS location coordinates
# * Create and export the model Y-Bus Matrix
#
# ## Getting Started
#
# Before running any of the sample routines in this tutorial, it is first necessary to start the GridAPPS-D Platform and establish a connection to this notebook so that we can start passing calls to the API.

# %% [markdown]
# _Open the Ubuntu terminal and start the GridAPPS-D Platform if it is not running already:_
#
# `cd gridappsd-docker`
#
# ~/gridappsd-docker$ `./run.sh -t develop`
#
# _Once containers are running,_
#
# gridappsd@[container]:/gridappsd$ `./run-gridappsd.sh`

# %%
# Establish connection to GridAPPS-D Platform:
from gridappsd import GridAPPSD
gapps = GridAPPSD("('localhost', 61613)", username='system', password='manager')
model_mrid = "_49AD8E07-3BF9-A4E2-CB8F-C3722F837B62" # IEEE 13 Node used for all example queries

# %% [markdown]
# ---
# # Table of Contents
#
# * [1. Introduction to the Configuration File API](#1.-Introduction-to-the-Configuration-File-API)
#
#
# * [2. Using the Configuration File API](#2.-Using-the-Configuration-File-API)
#     * [2.1. Specifying the Topic](#2.1.-Specifying-the-Topic)
#     * [2.2. Structure of a Query Message](#2.2.-Structure-of-a-Query-Message)
#     * [2.3. Specifying the configurationType](#2.3.-Specifying-the-configurationType)
#
#
# * [3. Querying for Feeder Model Info](#3.-Querying-for-Feeder-Model-Info)
#     * [3.1. Query for all GridLab-D Files](#3.1.-Query-for-all-GridLab-D-Files)
#     * [3.2. Query for GridLab-D Base GLM File](#3.2.-Query-for-GridLab-D-Base-GLM-File)
#     * [3.3. Query for GridLab-D Symbols File](#3.3.-Query-for-GridLab-D-Symbols-File)
#     * [3.4. Query for GridLab-D Measurement Types](#3.4.-Query-for-GridLab-D-Measurement-Types)
#
#
# * [4. Querying for CIM Dictionary Files](#4.-Querying-for-CIM-Dictionary-Files)
#     * [4.1. Query for CIM Model Dictionary](#4.1.-Query-for-Model-Dictionary)
#     * [4.2. Query for CIM Feeder Index](#4.2.-Query-for-CIM-Feeder-Index)
#
#
# * [5. Querying for OpenDSS Configuration Files](#5.-Querying-for-OpenDSS-Configuration-Files)
#     * [5.1. Query for all OpenDSS Files](#5.1.-Query-for-all-OpenDSS-Files)
#     * [5.2. Query for OpenDSS Base File](#5.2.-Query-for-OpenDSS-Base-File)
#     * [5.3. Query for OpenDSS Coordinate File](#5.3.-Query-for-OpenDSS-Coordinate-File)
#     * [5.4.-Query for Y-Bus Matrix](#5.4.-Query-for-Y-Bus-Matrix)

# %% [markdown]
# ---
# # 1. Introduction to the Configuration File API
#
#
# The Configuration File API is used to generate power system models that can be solved in GridLab-D or OpenDSS based on the original CIM XML model. The load profile and ZIP parameters can be modified from the nominal values prior to model creation and export.

# %% [markdown]
# ---
# # 2. Using the Configuration File API

# %% [markdown]
# ## 2.1. Specifying the Topic
#
# All queries passed to the Simulation API need to use the correct topic.For a review of GridAPPS-D topics, see Lesson 1.4 There are two ways to specify the topic. Both produce identical results.

# %% [markdown]
# __1) Specifying the topic as a string:__

# %%
topic = "goss.gridappsd.process.request.config"

# %% [markdown]
# __2) Using the topics library to specify the topic:__

# %%
from gridappsd import topics as t
topic = t.CONFIG

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 2.2. Structure of a Query Message
#
# Queries passed to Configuration File API are formatted as python dictionaries or equivalent JSON scripts wrapped as a python string.
#
# The accepted set of key-value pairs for the Configuration File API query message is
#
# ```
# message = {
#     "configurationType": "INSERT QUERY HERE",
#     "parameters": {
#         "key1": "value1",
#         "key2": "value2"}
# }
# ```
#
# The components of the message are as follows:
#
# * `"configurationType":` -- Specifies the type of configuration file requested.
#
#
# * `"parameters":` -- Specifies any specific power system model parameters. Values depend on the particular configurationType.
#
#
# The usage of each of these message components are explained in detail with code block examples below.
#
# __Important__: Be sure to pay attention to placement of commas ( __,__ ) at the end of each JSON line. Commas are placed at the end of each line _except_ the last line. Incorrect comma placement will result in a JsonSyntaxException.
#
# All of the queries are passed to the Configuration API using the `.get_response(topic, message)` method for the GridAPPS-D platform connection variable.

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 2.3. Specifying the `configurationType`
#
# Below are the possible `configurationType` key-value pairs that are used to specify the type of each query. Executable code block examples are provided for each of the requests in the subsections below.
#
# The first group of _configurationType_ key-value pairs are for queries for information related to the GridLab-D GLM files and settings:
#
#
# * `"configurationType": "GridLab-D All"` -- [Query for all GridLab-D files](#3.1.-Query-for-all-GridLab-D-Files)
#
#
# * `"configurationType": "GridLab-D Base GLM"` -- [Query for GridLab-D base GLM file](#3.2.-Query-for-GridLab-D-Base-GLM-File)
#
#
# * `"configurationType": "GridLab-D Symbols"` -- [Query for GridLab-D symbols file](#3.3.-Query-for-GridLab-D-Symbols-File)
#
#
# * `"configurationType": "GridLab-D Simulation Output"` -- [Query for available measurement types](#3.4.-Query-for-GridLab-D-Measurement-Types)

# %% [markdown]
# The second group of _configurationType_ are for queries for CIM dictionary and feeder index files:
#
# * `"configurationType": "CIM Dictionary"` -- [Query for python dictionary of CIM XML model](#4.1.-Query-for-Model-Dictionary)
#
#
# * `"configurationType": "CIM Feeder Index"` -- [Query for python dictionary of model mRIDs](#4.2.-Query-for-CIM-Feeder-Index)

# %% [markdown]
# The third group of _configurationType_ key-value pairs are for queries for OpenDSS model files
#
#
# * `"configurationType": "DSS All"` -- [Query for all OpenDSS model files](#5.1.-Query-for-all-OpenDSS-Files)
#
#
# * `"configurationType": "DSS Base"` -- [Query for OpenDSS version of power system model](#5.2.-Query-for-OpenDSS-Base-File)
#
#
# * `"configurationType": "DSS Coordinate"` -- [Query for list of OpenDSS XY coordinates](#5.3.-Query-for-OpenDSS-Coordinate-File)
#
#
# * `"configurationType": "YBus Export"` -- [Export Y-Bus matrix from OpenDSS](#5.4.-Query-for-Y-Bus-Matrix)

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# # 3. Querying for GridLab-D Configuration Files
#
# This section outlines the details of key-value pairs for the possible queries associated with each value of the `queryMeasurement` key listed above.

# %% [markdown]
# ## 3.1. Query for all GridLab-D Files
#
# This API call generates all the GLM files necessary to solve the power system model in GridLab-D. The query returns a directory where the set of GLM files are located.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D All"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                 "directory":                          output directory as string ,
#                 "simulation_name":                    string ,
#                 "simulation_start_time":              epoch time number ,
#                 "simulation_duration":                number ,
#                 "simulation_id":                      number ,
#                 "simulation_broker_host":             string ,
#                 "simulation_broker_port":             number ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string ,
#                 "solver_method":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.

# %% [markdown]
# __Example: Export IEEE 13 node model with constant current loads to GLM files :__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D All",
    "parameters": {
        "directory": "/tmp/gridlabdsimulation/",
        "model_id": model_mrid,
        "simulation_id": "12345678",
        "simulation_name": "mysimulation",
        "simulation_start_time": "1518958800",
        "simulation_duration": "60",
        "simulation_broker_host": "localhost",
        "simulation_broker_port": "61616",
        "schedule_name": "ieeezipload",
        "load_scaling_factor": "1.0",
        "z_fraction": "0.0",
        "i_fraction": "1.0",
        "p_fraction": "0.0",
        "solver_method": "NR" }
}

gapps.get_response(topic, message, timeout = 120)

# %% [markdown]
# __Note:__ The output directory is inside the GridAPPS-D Docker Container, not in your Ubuntu or Windows environment. To access the files, it is necessary to change directories to those inside the docker container.
#
# Open a new Ubuntu terminal and run:
# * `docker exec -it gridappsd-docker_gridappsd_1 bash`
# * `cd /tmp/gridlabdsimulation`
# * `ls -l`
#
# To copy the files to your regular directory, see Lesson 0.XX (to be released shortly) on working with Docker containers.

# %% [markdown]
# ![2_7_config_file_docker_directory.png](attachment:2_7_config_file_docker_directory.png)

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 3.2. Query for GridLab-D Base GLM File
#
# This API call generates a single GLM file that contains the entire power system model that can be solved in GridLab-D. The query returns the entire model GLM file wrapped in a python dictionary.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D Base GLM"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.

# %% [markdown]
# __Example 1: Create GLM base file using nominal load values:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Base GLM",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message, timeout = 60)

# %% [markdown]
# __Example 2: Create GLM base file using all constant current loads and hourly load curve:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Base GLM",
    "parameters": {
        "model_id": model_mrid,
        "load_scaling_factor": "1.0",
        "z_fraction": 0.0,
        "i_fraction": 1.0,
        "p_fraction": "0.0",
        "schedule_name": "ieeezipload"}
}

gapps.get_response(topic, message, timeout = 60)

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 3.3. Query for GridLab-D Symbols File
#
# This API call generates a file with all the XY coordinates used by GridLab-D when running a simulation.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D Symbols"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Symbols",
    "parameters": { "model_id": model_mrid }
}

gapps.get_response(topic, message)

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 3.4. Query for GridLab-D Measurement Types
#
# This API call returns a list of device names and types of available measurement in the GridLab-D format (__not__ CIM classes or measurement mRIDs)
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D Simulation Output"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Simulation Output",
    "parameters":{"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ---
# # 4. Querying for CIM Dictionary Files
#
# ## 4.1. Query for Model Dictionary
#
# This API generates a python dictionary which maps the CIM mRIDs of objects in the power system model to names of model objects used in other simulators.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "CIM Dictionary"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "CIM Dictionary",
    "parameters":{"model_id": "_AAE94E4A-2465-6F5E-37B1-3E72183A4E44"}
}

gapps.get_response(topic, message, timeout = 30)
# Out:
# {'data': {'feeders': [{'name': 'test9500new',
#     'mRID': '_AAE94E4A-2465-6F5E-37B1-3E72183A4E44',
#     'substation': 'ThreeSubs',
#     'substationID': '_40485321-9B2C-1B8C-EC33-39D2F7948163',
#     'subregion': 'Large',
#     'subregionID': '_A1170111-942A-6ABD-D325-C64886DC4D7D',
#     'region': 'IEEE',
#     'regionID': '_73C512BD-7249-4F50-50DA-D93849B89C43',
#     'synchronousmachines': [{'name': 'diesel590',
#       'mRID': '_071BAF74-94D7-46AD-92B4-571B2DE33F8A',
#       'CN1': 'm1089-dies1',
#       'phases': 'ABC',
#       'ratedS': 737000.0,
#       'ratedU': 480.0,
#       'p': 0.0,
#       'q': 0.0},
#      {'name': 'diesel620',
#       'mRID': '_F4FABAA8-6368-4B6A-8406-84973DCFDD9C',
#       'CN1': 'm1209-dies1',
#       'phases': 'ABC',
#       'ratedS': 775000.0,
#       'ratedU': 480.0,
#       'p': 0.0,
#       'q': 0.0},
#      {'name': 'lngengine100',
#       'mRID': '_05729D45-D948-4CDA-834F-758637D69A28',
#       'CN1': 'm1142-lng1',
#       'phases': 'ABC',
#       'ratedS': 125000.0,
#       'ratedU': 480.0,
#       'p': 0.0,
#       'q': 0.0},
#      {'name': 'lngengine1800',
#       'mRID': '_0EC0C5DD-6A16-40B0-A97B-F4C18D1BE15A',
#       'CN1': 'm1089-lng1',
#       'phases': 'ABC',
#       'ratedS': 2250000.0,
#       'ratedU': 480.0,
#       'p': 0.0,
#       'q': 0.0},
#      {'name': 'microturb-1',
#       'mRID': '_F5C0D7EB-09AF-4A68-806C-CD77A83657CD',
#       'CN1': 'm2001-mt1',
#       'phases': 'ABC',
#       'ratedS': 250000.0,
#       'ratedU': 480.0,
#       'p': 50000.0,
#       'q': 24216.105},
#      {'name': 'microturb-2',
#       'mRID': '_0B1196E3-5331-4025-BAFF-2737EE3769B5',
#       'CN1': 'm2001-mt2',
#       'phases': 'ABC',
#       'ratedS': 250000.0,
#       'ratedU': 480.0,
#       'p': 0.0,
#       'q': 0.0},
#      {'name': 'microturb-3',
#       'mRID': '_534ADCAF-1DD2-4327-8F60-9CFFF5090021',
#       'CN1': 'm2001-mt3',
#       'phases': 'ABC',
#       'ratedS': 250000.0,
#       'ratedU': 480.0,
#       'p': 0.0,
#       'q': 0.0},
#      {'name': 'microturb-4',
#       'mRID': '_D961F191-18B1-40DF-BC38-C1ED76B819AC',
#       'CN1': 'm1069-mt1',
#       'phases': 'ABC',
#       'ratedS': 250000.0,
#       'ratedU': 480.0,
#       'p': 100000.0,
#       'q': 48432.21},
#      {'name': 'pvfarm1',
#       'mRID': '_84E48FCB-16C4-4D82-8457-7BBE86825E57',
#       'CN1': 'm1047pv-3',
#       'phases': 'ABC',
#       'ratedS': 750000.0,
#       'ratedU': 12470.0,
#       'p': 450000.0,
#       'q': 90000.0},
#      {'name': 'steamgen1',
#       'mRID': '_835F365B-A927-473C-A008-4B94C237F698',
#       'CN1': 'm1026chp-3',
#       'phases': 'ABC',
#       'ratedS': 4000000.0,
#       'ratedU': 12470.0,
#       'p': 1000000.0,
#       'q': -1079485.6}],
#     'capacitors': [{'name': 'capbank0a',
#       'mRID': '_CD518165-0BA4-4FE7-A9F8-5EB537048CAD',
#       'CN1': 'r42246',
#       'phases': 'A',
#       'kvar_A': 400.0,
#       'kvar_B': 0.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -50000.0,
#       'targetDeadband': -500000.0,
#       'aVRDelay': 100.0,
#       'monitoredName': 'cap_3a',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16642',
#       'monitoredPhase': 'A'},
#      {'name': 'capbank0b',
#       'mRID': '_46A24469-DBEC-4E80-A085-DDC91363CB3E',
#       'CN1': 'r42246',
#       'phases': 'B',
#       'kvar_A': 0.0,
#       'kvar_B': 400.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -50000.0,
#       'targetDeadband': -500000.0,
#       'aVRDelay': 101.0,
#       'monitoredName': 'cap_3b',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16642',
#       'monitoredPhase': 'B'},
#      {'name': 'capbank0c',
#       'mRID': '_A40E8828-7E09-40F7-9AC7-69912D6202FB',
#       'CN1': 'r42246',
#       'phases': 'C',
#       'kvar_A': 0.0,
#       'kvar_B': 0.0,
#       'kvar_C': 400.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -50000.0,
#       'targetDeadband': -500000.0,
#       'aVRDelay': 102.0,
#       'monitoredName': 'cap_3c',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16642',
#       'monitoredPhase': 'C'},
#      {'name': 'capbank1a',
#       'mRID': '_940621CF-B916-4B51-AEE1-EE79FD2504E3',
#       'CN1': 'r42247',
#       'phases': 'A',
#       'kvar_A': 300.0,
#       'kvar_B': 0.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 100.0,
#       'monitoredName': 'cap_2a',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16483',
#       'monitoredPhase': 'A'},
#      {'name': 'capbank1b',
#       'mRID': '_3AF8E253-6374-4189-B866-94521E0902F5',
#       'CN1': 'r42247',
#       'phases': 'B',
#       'kvar_A': 0.0,
#       'kvar_B': 300.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 101.0,
#       'monitoredName': 'cap_2b',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16483',
#       'monitoredPhase': 'B'},
#      {'name': 'capbank1c',
#       'mRID': '_2C4D01FA-8F59-488F-A3C3-8155C66A4ADF',
#       'CN1': 'r42247',
#       'phases': 'C',
#       'kvar_A': 0.0,
#       'kvar_B': 0.0,
#       'kvar_C': 300.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 102.0,
#       'monitoredName': 'cap_2c',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16483',
#       'monitoredPhase': 'C'},
#      {'name': 'capbank2a',
#       'mRID': '_144989E5-38F6-49EE-9FD4-F9404C7CAB8E',
#       'CN1': 'r20185',
#       'phases': 'A',
#       'kvar_A': 300.0,
#       'kvar_B': 0.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 100.0,
#       'monitoredName': 'cap_1a',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'l2823592',
#       'monitoredPhase': 'A'},
#      {'name': 'capbank2b',
#       'mRID': '_D1AEA101-59AD-4AB6-9C2C-47CAC0A3473B',
#       'CN1': 'r20185',
#       'phases': 'B',
#       'kvar_A': 0.0,
#       'kvar_B': 300.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 101.0,
#       'monitoredName': 'cap_1b',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'l2823592',
#       'monitoredPhase': 'B'},
#      {'name': 'capbank2c',
#       'mRID': '_2743CCA1-F47B-4344-8DA1-92427E1F701D',
#       'CN1': 'r20185',
#       'phases': 'C',
#       'kvar_A': 0.0,
#       'kvar_B': 0.0,
#       'kvar_C': 300.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 102.0,
#       'monitoredName': 'cap_1c',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'l2823592',
#       'monitoredPhase': 'C'},
#      {'name': 'capbank3',
#       'mRID': '_C67AB4BD-1BD0-484C-AB3B-0142DD83E4DB',
#       'CN1': 'r18242',
#       'phases': 'ABC',
#       'kvar_A': 300.0,
#       'kvar_B': 300.0,
#       'kvar_C': 300.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 12471.1,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': False,
#       'mode': None,
#       'targetValue': 0.0,
#       'targetDeadband': 0.0,
#       'aVRDelay': 0.0,
#       'monitoredName': None,
#       'monitoredClass': None,
#       'monitoredBus': None,
#       'monitoredPhase': None}],
#     'regulators': [{'bankName': 'feeder_reg1a',
#       'size': '1',
#       'bankPhases': 'A',
#       'tankName': ['feeder_reg1a'],
#       'endNumber': [2],
#       'endPhase': ['A'],
#       'rtcName': ['feeder_reg1a'],
#       'mRID': ['_83B9C813-2AC0-42E7-99CA-2F8D71BD5A23'],
#       'monitoredPhase': ['A'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-3],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg1b',
#       'size': '1',
#       'bankPhases': 'B',
#       'tankName': ['feeder_reg1b'],
#       'endNumber': [2],
#       'endPhase': ['B'],
#       'rtcName': ['feeder_reg1b'],
#       'mRID': ['_1C7E9E56-8645-45A1-B6E3-8B48FEBDF4B5'],
#       'monitoredPhase': ['B'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-3],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg1c',
#       'size': '1',
#       'bankPhases': 'C',
#       'tankName': ['feeder_reg1c'],
#       'endNumber': [2],
#       'endPhase': ['C'],
#       'rtcName': ['feeder_reg1c'],
#       'mRID': ['_43D3C659-1EFA-4654-9FF3-D948E0FE03BF'],
#       'monitoredPhase': ['C'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-3],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg2a',
#       'size': '1',
#       'bankPhases': 'A',
#       'tankName': ['feeder_reg2a'],
#       'endNumber': [2],
#       'endPhase': ['A'],
#       'rtcName': ['feeder_reg2a'],
#       'mRID': ['_1A0288B6-1D4F-4684-B4FE-5FA88F3A8CCE'],
#       'monitoredPhase': ['A'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-2],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg2b',
#       'size': '1',
#       'bankPhases': 'B',
#       'tankName': ['feeder_reg2b'],
#       'endNumber': [2],
#       'endPhase': ['B'],
#       'rtcName': ['feeder_reg2b'],
#       'mRID': ['_D8610C82-7E69-4B13-A9EF-59D3511ACB0F'],
#       'monitoredPhase': ['B'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-2],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg2c',
#       'size': '1',
#       'bankPhases': 'C',
#       'tankName': ['feeder_reg2c'],
#       'endNumber': [2],
#       'endPhase': ['C'],
#       'rtcName': ['feeder_reg2c'],
#       'mRID': ['_3A2A6C3C-3EEE-4436-B899-400617ABCC2E'],
#       'monitoredPhase': ['C'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-3],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg3a',
#       'size': '1',
#       'bankPhases': 'A',
#       'tankName': ['feeder_reg3a'],
#       'endNumber': [2],
#       'endPhase': ['A'],
#       'rtcName': ['feeder_reg3a'],
#       'mRID': ['_A7374EB9-8146-4675-8E04-FEAF2FEDADA7'],
#       'monitoredPhase': ['A'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-1],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg3b',
#       'size': '1',
#       'bankPhases': 'B',
#       'tankName': ['feeder_reg3b'],
#       'endNumber': [2],
#       'endPhase': ['B'],
#       'rtcName': ['feeder_reg3b'],
#       'mRID': ['_62B747D6-EA3B-4806-9F8B-BDD010FCB594'],
#       'monitoredPhase': ['B'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-1],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'feeder_reg3c',
#       'size': '1',
#       'bankPhases': 'C',
#       'tankName': ['feeder_reg3c'],
#       'endNumber': [2],
#       'endPhase': ['C'],
#       'rtcName': ['feeder_reg3c'],
#       'mRID': ['_295D1CAD-14E1-4EEA-9568-DFF4AE3EF068'],
#       'monitoredPhase': ['C'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-2],
#       'targetValue': [123.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg2_a',
#       'size': '1',
#       'bankPhases': 'A',
#       'tankName': ['vreg2_a'],
#       'endNumber': [2],
#       'endPhase': ['A'],
#       'rtcName': ['vreg2_a'],
#       'mRID': ['_14239F57-9B5A-41CA-B28D-0AA18DF40149'],
#       'monitoredPhase': ['A'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-7],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg2_b',
#       'size': '1',
#       'bankPhases': 'B',
#       'tankName': ['vreg2_b'],
#       'endNumber': [2],
#       'endPhase': ['B'],
#       'rtcName': ['vreg2_b'],
#       'mRID': ['_E37DD82C-6A9C-44AF-A8D0-909593E805E3'],
#       'monitoredPhase': ['B'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-3],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg2_c',
#       'size': '1',
#       'bankPhases': 'C',
#       'tankName': ['vreg2_c'],
#       'endNumber': [2],
#       'endPhase': ['C'],
#       'rtcName': ['vreg2_c'],
#       'mRID': ['_38C3530D-4042-4C0D-8022-2FADAF691153'],
#       'monitoredPhase': ['C'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-1],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg3_a',
#       'size': '1',
#       'bankPhases': 'A',
#       'tankName': ['vreg3_a'],
#       'endNumber': [2],
#       'endPhase': ['A'],
#       'rtcName': ['vreg3_a'],
#       'mRID': ['_ECAE730A-872C-4932-B09F-94F79AB5A0CF'],
#       'monitoredPhase': ['A'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [5],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg3_b',
#       'size': '1',
#       'bankPhases': 'B',
#       'tankName': ['vreg3_b'],
#       'endNumber': [2],
#       'endPhase': ['B'],
#       'rtcName': ['vreg3_b'],
#       'mRID': ['_1D26FA5B-2C24-4985-A8B5-E4122294674E'],
#       'monitoredPhase': ['B'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [5],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg3_c',
#       'size': '1',
#       'bankPhases': 'C',
#       'tankName': ['vreg3_c'],
#       'endNumber': [2],
#       'endPhase': ['C'],
#       'rtcName': ['vreg3_c'],
#       'mRID': ['_5D67EBEE-9158-4C56-9E39-12A9AC0D7B8D'],
#       'monitoredPhase': ['C'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [4],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg4_a',
#       'size': '1',
#       'bankPhases': 'A',
#       'tankName': ['vreg4_a'],
#       'endNumber': [2],
#       'endPhase': ['A'],
#       'rtcName': ['vreg4_a'],
#       'mRID': ['_8B7CC6A2-B498-4103-96B0-A8122066CBCD'],
#       'monitoredPhase': ['A'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-3],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg4_b',
#       'size': '1',
#       'bankPhases': 'B',
#       'tankName': ['vreg4_b'],
#       'endNumber': [2],
#       'endPhase': ['B'],
#       'rtcName': ['vreg4_b'],
#       'mRID': ['_1917DB57-8D52-4B9C-8887-9029164C5B69'],
#       'monitoredPhase': ['B'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-4],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]},
#      {'bankName': 'vreg4_c',
#       'size': '1',
#       'bankPhases': 'C',
#       'tankName': ['vreg4_c'],
#       'endNumber': [2],
#       'endPhase': ['C'],
#       'rtcName': ['vreg4_c'],
#       'mRID': ['_7C8CFB6C-CB34-4218-8828-8A8819EBF82C'],
#       'monitoredPhase': ['C'],
#       'TapChanger.tculControlMode': ['volt'],
#       'highStep': [16],
#       'lowStep': [-16],
#       'neutralStep': [0],
#       'normalStep': [0],
#       'TapChanger.controlEnabled': [True],
#       'lineDropCompensation': [False],
#       'ltcFlag': [True],
#       'RegulatingControl.enabled': [True],
#       'RegulatingControl.discrete': [True],
#       'RegulatingControl.mode': ['voltage'],
#       'step': [-5],
#       'targetValue': [125.0],
#       'targetDeadband': [2.0],
#       'limitVoltage': [0.0],
#       'stepVoltageIncrement': [0.625],
#       'neutralU': [7200.0],
#       'initialDelay': [15.0],
#       'subsequentDelay': [2.0],
#       'lineDropR': [0.0],
#       'lineDropX': [0.0],
#       'reverseLineDropR': [0.0],
#       'reverseLineDropX': [0.0],
#       'ctRating': [300.0],
#       'ctRatio': [1500.0],
#       'ptRatio': [60.0]}],
#     'solarpanels': [{'name': 'pv_10',
#       'mRID': '_353EB14D-D837-4D1A-A0C7-C04C4230B321',
#       'CN1': 'sx2000406a',
#       'phases': 's1:s2',
#       'ratedS': 15740.0,
#       'ratedU': 208.0,
#       'p': 12600.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_100',
#       'mRID': '_6EACE642-2488-4867-B610-6CFF60048BBA',
#       'CN1': 'sx2001009b',
#       'phases': 's2:s1',
#       'ratedS': 17460.0,
#       'ratedU': 208.0,
#       'p': 13970.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1001',
#       'mRID': '_A2B47688-0ED8-45CF-9882-2D425DBC6C8C',
#       'CN1': 'sx3216348a',
#       'phases': 's1:s2',
#       'ratedS': 6600.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1003',
#       'mRID': '_92D922CF-8095-48F4-B749-B594C1545D73',
#       'CN1': 'sx2673331b',
#       'phases': 's2:s1',
#       'ratedS': 24300.0,
#       'ratedU': 208.0,
#       'p': 19450.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1005',
#       'mRID': '_5A29A6CE-975E-4431-BEC5-251BC0D5B170',
#       'CN1': 'sx3045895c',
#       'phases': 's1:s2',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1007',
#       'mRID': '_D12EBB01-412A-4A48-8B6A-4E1CC66912FB',
#       'CN1': 'sx3104126c',
#       'phases': 's2:s1',
#       'ratedS': 5100.0,
#       'ratedU': 208.0,
#       'p': 4070.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1009',
#       'mRID': '_B1DCF43B-E86C-45AA-ABDE-0504D2C7E916',
#       'CN1': 'sx2691946b',
#       'phases': 's2:s1',
#       'ratedS': 7300.0,
#       'ratedU': 208.0,
#       'p': 5850.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1011',
#       'mRID': '_C2D6C67C-BFAA-4058-AAD6-502678CAD9C6',
#       'CN1': 'sx3010565c',
#       'phases': 's1:s2',
#       'ratedS': 5100.0,
#       'ratedU': 208.0,
#       'p': 4070.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1013',
#       'mRID': '_BB63999C-C99C-41F8-B6CD-0C459C0BFD21',
#       'CN1': 'sx2710543c',
#       'phases': 's1:s2',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1015',
#       'mRID': '_BE9F64F0-91CB-47E5-86A4-103D1B8F22C1',
#       'CN1': 'sx3085410b',
#       'phases': 's2:s1',
#       'ratedS': 7300.0,
#       'ratedU': 208.0,
#       'p': 5840.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1017',
#       'mRID': '_1562BCFC-A681-4DA6-8F61-983CA6316CF3',
#       'CN1': 'sx2861197c',
#       'phases': 's1:s2',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1019',
#       'mRID': '_4CB09FF8-5159-48C6-BBB0-361CE5B3AC4E',
#       'CN1': 'sx2841636b',
#       'phases': 's1:s2',
#       'ratedS': 7300.0,
#       'ratedU': 208.0,
#       'p': 5840.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_102',
#       'mRID': '_60EB4EF5-97A0-47AA-99A9-52E225565D3E',
#       'CN1': 'sx2001010b',
#       'phases': 's1:s2',
#       'ratedS': 21120.0,
#       'ratedU': 208.0,
#       'p': 16900.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1021',
#       'mRID': '_D6AADAB0-5D9B-4E1A-A51D-0035A72176B3',
#       'CN1': 'sx2955005b',
#       'phases': 's1:s2',
#       'ratedS': 7300.0,
#       'ratedU': 208.0,
#       'p': 5840.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1023',
#       'mRID': '_7306AB26-0EFB-430A-AB29-8EDDB4FABBA2',
#       'CN1': 'sx3254214b',
#       'phases': 's1:s2',
#       'ratedS': 12200.0,
#       'ratedU': 208.0,
#       'p': 9730.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1025',
#       'mRID': '_92495B0F-5932-45D0-90E0-2C8783420518',
#       'CN1': 'sx3048965b',
#       'phases': 's2:s1',
#       'ratedS': 18200.0,
#       'ratedU': 208.0,
#       'p': 14590.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1027',
#       'mRID': '_4AA918E6-8A56-4D85-96A6-D8261B72956E',
#       'CN1': 'sx2674051a',
#       'phases': 's2:s1',
#       'ratedS': 6600.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1029',
#       'mRID': '_3C0FADB6-2D09-493A-8D50-F2D83E317BF0',
#       'CN1': 'sx2804252a',
#       'phases': 's1:s2',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1031',
#       'mRID': '_995E70A6-3CFC-4DE3-AAB4-CAF97E51770C',
#       'CN1': 'sx3178981b',
#       'phases': 's1:s2',
#       'ratedS': 12100.0,
#       'ratedU': 208.0,
#       'p': 9730.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1033',
#       'mRID': '_3579A585-6FCF-48F5-891E-D89D48D72474',
#       'CN1': 'sx2710510c',
#       'phases': 's1:s2',
#       'ratedS': 5100.0,
#       'ratedU': 208.0,
#       'p': 4070.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1035',
#       'mRID': '_943FC86B-5C80-4A8A-B487-C8FCAD06346D',
#       'CN1': 'sx2935551c',
#       'phases': 's2:s1',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1037',
#       'mRID': '_1EDBD1EE-636D-478D-9469-A63AA3A875C9',
#       'CN1': 'sx2729428a',
#       'phases': 's1:s2',
#       'ratedS': 6700.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1039',
#       'mRID': '_DD391CF4-2764-4CCE-B7FC-CBE5ADCB03AA',
#       'CN1': 'sx2766721a',
#       'phases': 's1:s2',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_104',
#       'mRID': '_51E304A7-DEF0-4BD7-A425-FCCB5C22E397',
#       'CN1': 'sx2001011b',
#       'phases': 's1:s2',
#       'ratedS': 9350.0,
#       'ratedU': 208.0,
#       'p': 7480.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1041',
#       'mRID': '_747D9B1D-56C6-4531-906B-59E319B8810E',
#       'CN1': 'sx2803199b',
#       'phases': 's1:s2',
#       'ratedS': 24300.0,
#       'ratedU': 208.0,
#       'p': 19450.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1043',
#       'mRID': '_37E6DACC-EC95-44DA-BBF0-F3BA9CBC6D8D',
#       'CN1': 'sx2804272b',
#       'phases': 's1:s2',
#       'ratedS': 7300.0,
#       'ratedU': 208.0,
#       'p': 5840.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1045',
#       'mRID': '_6CF0617A-CE94-452F-9340-50B04843D756',
#       'CN1': 'sx3216347c',
#       'phases': 's1:s2',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1047',
#       'mRID': '_B1561003-9A91-46D5-B16F-E188F4E558CE',
#       'CN1': 'sx3104155c',
#       'phases': 's1:s2',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1049',
#       'mRID': '_A50F6E3E-08C7-4FCF-A6A5-A2B137BE4BD2',
#       'CN1': 'sx2814529c',
#       'phases': 's2:s1',
#       'ratedS': 25400.0,
#       'ratedU': 208.0,
#       'p': 20340.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1051',
#       'mRID': '_0E47F55A-5098-4A76-80B2-9A34200BB078',
#       'CN1': 'sx3048937c',
#       'phases': 's2:s1',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1053',
#       'mRID': '_BC18AF7F-6F03-40A6-A924-6D99D3AD7544',
#       'CN1': 'sx2710544a',
#       'phases': 's1:s2',
#       'ratedS': 6700.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1055',
#       'mRID': '_0ECD956A-D9E7-435A-AFC7-55DC76CDDC0B',
#       'CN1': 'sx2839305a',
#       'phases': 's1:s2',
#       'ratedS': 6700.0,
#       'ratedU': 208.0,
#       'p': 5330.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1057',
#       'mRID': '_2C847309-75CD-4ECA-BF4F-7A0F390BAA16',
#       'CN1': 'sx3160113b',
#       'phases': 's2:s1',
#       'ratedS': 12100.0,
#       'ratedU': 208.0,
#       'p': 9730.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1059',
#       'mRID': '_5309081D-862B-40F9-8D74-A0869C36326A',
#       'CN1': 'sx2673318c',
#       'phases': 's2:s1',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_106',
#       'mRID': '_F6B31339-7A23-4B24-878A-C799183D7D8D',
#       'CN1': 'sx2001012b',
#       'phases': 's1:s2',
#       'ratedS': 17200.0,
#       'ratedU': 208.0,
#       'p': 13750.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1061',
#       'mRID': '_F9BA185A-619B-41EE-A001-58B00B00F4A2',
#       'CN1': 'sx2992556c',
#       'phases': 's2:s1',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1063',
#       'mRID': '_2F031E4B-1B2A-4A58-90DF-365E9D457880',
#       'CN1': 'sx2814529a',
#       'phases': 's1:s2',
#       'ratedS': 22100.0,
#       'ratedU': 208.0,
#       'p': 17740.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1065',
#       'mRID': '_721C3322-001F-43B1-8A40-24C94DCE0883',
#       'CN1': 'sx2785523c',
#       'phases': 's1:s2',
#       'ratedS': 7700.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1067',
#       'mRID': '_50731D12-2EB6-4745-959E-32F3C2F70F80',
#       'CN1': 'sx2841638c',
#       'phases': 's2:s1',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1069',
#       'mRID': '_CFB296B2-AD4D-4681-8921-F791DDC0B870',
#       'CN1': 'sx3216368c',
#       'phases': 's2:s1',
#       'ratedS': 7700.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1071',
#       'mRID': '_94B5CB93-A796-45EC-B1F9-EBCFA221DBA6',
#       'CN1': 'sx2841627a',
#       'phases': 's2:s1',
#       'ratedS': 6700.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1073',
#       'mRID': '_C6048805-3F8F-4519-A005-0F22E7F3EF2F',
#       'CN1': 'sx3197641a',
#       'phases': 's1:s2',
#       'ratedS': 6700.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1075',
#       'mRID': '_40FA345C-4ABF-4E90-8546-0EA56B60C10F',
#       'CN1': 'sx2673319c',
#       'phases': 's2:s1',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1077',
#       'mRID': '_F3A93450-98B1-4222-AF94-FA367BCA3EA1',
#       'CN1': 'sx2991943c',
#       'phases': 's1:s2',
#       'ratedS': 12800.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1079',
#       'mRID': '_F68D6505-26CE-4149-9B44-D539D6ACA713',
#       'CN1': 'sx2891575c',
#       'phases': 's1:s2',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_108',
#       'mRID': '_7237789A-6145-4836-B2DA-24EF0614C49D',
#       'CN1': 'sx2001013b',
#       'phases': 's2:s1',
#       'ratedS': 21960.0,
#       'ratedU': 208.0,
#       'p': 17570.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1081',
#       'mRID': '_E6D30845-F08E-4CD9-A9A6-6912C1EDDC60',
#       'CN1': 'sx2897767c',
#       'phases': 's2:s1',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1083',
#       'mRID': '_D6D1B045-20A5-46AE-8455-32B0DA8A6162',
#       'CN1': 'sx3179650b',
#       'phases': 's1:s2',
#       'ratedS': 7300.0,
#       'ratedU': 208.0,
#       'p': 5840.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1085',
#       'mRID': '_93036351-AFA0-49C8-BCDF-168617072E26',
#       'CN1': 'sx2897772a',
#       'phases': 's2:s1',
#       'ratedS': 6600.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1087',
#       'mRID': '_F5819EB3-DC8D-4688-BF04-8A5B3B7938D2',
#       'CN1': 'sx3160106a',
#       'phases': 's2:s1',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1089',
#       'mRID': '_512D85E8-FBE0-4F22-AAB8-09F776B240D8',
#       'CN1': 'sx3143999a',
#       'phases': 's1:s2',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1091',
#       'mRID': '_6C0C0C8A-8A88-42E5-98CC-D8477F93F824',
#       'CN1': 'sx3254231a',
#       'phases': 's1:s2',
#       'ratedS': 4500.0,
#       'ratedU': 208.0,
#       'p': 3550.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1093',
#       'mRID': '_034009B3-73A3-461E-8C88-8DE25EBBD7A5',
#       'CN1': 'sx2936279c',
#       'phases': 's1:s2',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1095',
#       'mRID': '_28FB5893-002C-41E0-A9CD-82D6FA3B6A26',
#       'CN1': 'sx2767409b',
#       'phases': 's1:s2',
#       'ratedS': 12100.0,
#       'ratedU': 208.0,
#       'p': 9730.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1097',
#       'mRID': '_D5573855-98C3-4532-AC71-75E199CF6E42',
#       'CN1': 'sx3067478a',
#       'phases': 's2:s1',
#       'ratedS': 16700.0,
#       'ratedU': 208.0,
#       'p': 13300.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1099',
#       'mRID': '_AC8E5D8A-085C-44B9-AACF-FE59382F9850',
#       'CN1': 'sx2691945c',
#       'phases': 's1:s2',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_110',
#       'mRID': '_20231744-9881-441F-975E-ABB9B13C7EB6',
#       'CN1': 'sx2001014b',
#       'phases': 's1:s2',
#       'ratedS': 35410.0,
#       'ratedU': 208.0,
#       'p': 28330.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1101',
#       'mRID': '_7142FAD2-4E28-4340-B980-DB1E02C7F1D8',
#       'CN1': 'sx3104132a',
#       'phases': 's2:s1',
#       'ratedS': 6600.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1103',
#       'mRID': '_4E5D37CC-C30A-4CEE-A499-039C9D14A484',
#       'CN1': 'sx2785538a',
#       'phases': 's2:s1',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1105',
#       'mRID': '_94860AF3-A4C0-4433-8A86-638D20E12076',
#       'CN1': 'sx2785513a',
#       'phases': 's1:s2',
#       'ratedS': 11000.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1107',
#       'mRID': '_ACB361AD-A3DC-4C46-B0A5-29F94E23EFC1',
#       'CN1': 'sx3082992a',
#       'phases': 's2:s1',
#       'ratedS': 6700.0,
#       'ratedU': 208.0,
#       'p': 5320.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1109',
#       'mRID': '_13622644-7326-4A7D-87B6-C35F94D0D93F',
#       'CN1': 'sx3178997c',
#       'phases': 's1:s2',
#       'ratedS': 7700.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1111',
#       'mRID': '_D14B7A6D-B100-40CB-B660-F4D070BD1D2B',
#       'CN1': 'sx3233412a',
#       'phases': 's1:s2',
#       'ratedS': 22200.0,
#       'ratedU': 208.0,
#       'p': 17740.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1113',
#       'mRID': '_ABDFFC85-03F3-4D13-A0E0-59638BC2B9E1',
#       'CN1': 'sx3215203a',
#       'phases': 's2:s1',
#       'ratedS': 22100.0,
#       'ratedU': 208.0,
#       'p': 17740.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1115',
#       'mRID': '_A22672C3-9B10-4378-8DB7-F4665DA5943B',
#       'CN1': 'sx3728043a',
#       'phases': 's2:s1',
#       'ratedS': 16700.0,
#       'ratedU': 208.0,
#       'p': 13300.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1117',
#       'mRID': '_D5A08BEC-52FD-43BD-8998-E7405D05865F',
#       'CN1': 'sx2897768c',
#       'phases': 's2:s1',
#       'ratedS': 12800.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1119',
#       'mRID': '_4DB5FF27-38D3-48CC-846D-C102995E69DE',
#       'CN1': 'sx2786274c',
#       'phases': 's1:s2',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_112',
#       'mRID': '_21D245A3-8ADF-43DA-95D2-FEE84DD3C06A',
#       'CN1': 'sx2001015b',
#       'phases': 's2:s1',
#       'ratedS': 30260.0,
#       'ratedU': 208.0,
#       'p': 24220.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1121',
#       'mRID': '_F85DF0BF-8DD3-4C64-BFC0-A701E19CE0A1',
#       'CN1': 'sx3217064b',
#       'phases': 's2:s1',
#       'ratedS': 12200.0,
#       'ratedU': 208.0,
#       'p': 9730.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1123',
#       'mRID': '_35FD149E-0D78-448A-A933-131514A59F8B',
#       'CN1': 'sx2805036b',
#       'phases': 's2:s1',
#       'ratedS': 4800.0,
#       'ratedU': 208.0,
#       'p': 3890.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1125',
#       'mRID': '_BA63651A-2F75-4D00-BB50-05C72E208BA1',
#       'CN1': 'sx3160862c',
#       'phases': 's2:s1',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1127',
#       'mRID': '_F8ACFD69-69B2-440D-9D9F-C84027AF2D9E',
#       'CN1': 'sx2936214a',
#       'phases': 's2:s1',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1129',
#       'mRID': '_8C9BEBB0-D6F9-43CA-9C22-6DDBAE5902E2',
#       'CN1': 'sx3104134c',
#       'phases': 's2:s1',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1131',
#       'mRID': '_E42204D8-EB1B-4026-8BDB-2B906791E58E',
#       'CN1': 'sx2955077c',
#       'phases': 's2:s1',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1133',
#       'mRID': '_BD8A67D5-59E8-4D38-BA6D-7085604FC9F8',
#       'CN1': 'sx2954350c',
#       'phases': 's2:s1',
#       'ratedS': 7600.0,
#       'ratedU': 208.0,
#       'p': 6100.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1135',
#       'mRID': '_CE7D365D-3785-4EE0-A5BF-A70C1B6B8507',
#       'CN1': 'sx2804283a',
#       'phases': 's1:s2',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1137',
#       'mRID': '_A2355A10-DC84-41BD-888F-1FC721C377EF',
#       'CN1': 'sx2841616a',
#       'phases': 's2:s1',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1139',
#       'mRID': '_F8FED3FC-68C4-4870-BB06-A20B028F3042',
#       'CN1': 'sx3011293c',
#       'phases': 's1:s2',
#       'ratedS': 25400.0,
#       'ratedU': 208.0,
#       'p': 20340.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_114',
#       'mRID': '_F05AD4DE-E2EA-4975-9EF5-1BF25CB1F841',
#       'CN1': 'sx2001202c',
#       'phases': 's1:s2',
#       'ratedS': 15530.0,
#       'ratedU': 208.0,
#       'p': 12430.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1141',
#       'mRID': '_08365641-1862-445E-B3E8-FA355E08FFF1',
#       'CN1': 'sx2766750c',
#       'phases': 's2:s1',
#       'ratedS': 19100.0,
#       'ratedU': 208.0,
#       'p': 15260.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1143',
#       'mRID': '_4BABC813-7642-493B-BE9B-854AA3BA6C55',
#       'CN1': 'sx2973148a',
#       'phases': 's1:s2',
#       'ratedS': 11100.0,
#       'ratedU': 208.0,
#       'p': 8870.0,
#       'q': 0.0,
#       'maxIFault': 1.111},
#      {'name': 'pv_1145',
#       'mRID': '_E1C74B3E-11D4-4101-B5CA-00A2DFD0AB78',
#       'CN1': 'sx3235243c',
#       'phases': 's2:s1',
#       'ratedS': 12700.0,
#       'ratedU': 208.0,
#       'p': 10170.0,
#       'q': 0.0,
# ...
#       'ConductingEquipment_mRID': '_754178D3-DFA3-4E31-BAB2-04332CD3C43E',
#       'Terminal_mRID': '_12DF2294-261D-474E-BB22-6B6FEF80B54A',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5985349-1',
#       'ConnectivityNode': 'm1069632',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_2224387113a0',
#       'mRID': '_0b055525-164e-4a44-b028-f85be280847f',
#       'ConductingEquipment_mRID': '_0EFA4E38-CC43-4477-A340-CF08522EDB12',
#       'Terminal_mRID': '_1EFDE15B-1621-48EF-AAA6-9BF42DF39F33',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '2224387113a0',
#       'ConnectivityNode': 'sx3728042a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5473449-1_Voltage',
#       'mRID': '_0b09fe13-e7a6-49ee-b5c4-f0d92457c8f9',
#       'ConductingEquipment_mRID': '_14899E6B-4A87-4323-8285-03F489791864',
#       'Terminal_mRID': '_4D9C7B85-8783-4B73-B07D-755D446F02D9',
#       'measurementType': 'PNV',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5473449-1',
#       'ConnectivityNode': 'l3179678',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6409778-1_Voltage',
#       'mRID': '_0b107d41-63bd-441d-8bac-dcc84d779848',
#       'ConductingEquipment_mRID': '_BBF260E8-BBF3-42F1-810B-57B1940016D6',
#       'Terminal_mRID': '_53BA99FF-9208-4645-A06A-CD7EDD20A7E2',
#       'measurementType': 'PNV',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6409778-1',
#       'ConnectivityNode': 'l2898495',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_226192926a0',
#       'mRID': '_0b113a5d-d86f-4f0b-8d10-adb152fde2d3',
#       'ConductingEquipment_mRID': '_937615CE-165D-478B-A44A-71044454D27D',
#       'Terminal_mRID': '_E0776EFC-B6AC-4BC4-9D74-B6A6D6B521E5',
#       'measurementType': 'VA',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '226192926a0',
#       'ConnectivityNode': 'sx2726973a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5865244-1_Voltage',
#       'mRID': '_0b12a543-e606-4b97-931b-44134dd085aa',
#       'ConductingEquipment_mRID': '_3EE50D0F-AEC8-4B15-8006-E0DD35F82BF6',
#       'Terminal_mRID': '_0A958D00-40AE-40D3-A9DA-5A7A3FD1DD72',
#       'measurementType': 'PNV',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5865244-1',
#       'ConnectivityNode': 'l2710517',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_337695b0',
#       'mRID': '_0b140994-4ea7-4d01-8451-f5d76bc09b78',
#       'ConductingEquipment_mRID': '_B895483F-AFD1-42BB-B57D-DE32C7B57D9D',
#       'Terminal_mRID': '_0A029AA2-D333-43F9-8FE8-33F94DFB3A03',
#       'measurementType': 'VA',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '337695b0',
#       'ConnectivityNode': 'sx2879072b',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_225571871b0',
#       'mRID': '_0b18c6a6-df5b-49c1-a789-883fb63bdd8c',
#       'ConductingEquipment_mRID': '_88EF3113-4186-4CC4-B82E-17A7E45B25A1',
#       'Terminal_mRID': '_11F3B07E-4310-4197-97BC-15C56E4C5FA5',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '225571871b0',
#       'ConnectivityNode': 'sx2911069b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5835125-1_Power',
#       'mRID': '_0b19e86f-1b2e-4ffa-befd-4e668ca381d5',
#       'ConductingEquipment_mRID': '_564AE060-8DF6-4FC1-87EF-C52907E206A1',
#       'Terminal_mRID': '_2573940A-5647-4C0F-BBE1-176FE7BFB7FD',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5835125-1',
#       'ConnectivityNode': 'm1008758',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx226193134c0_Voltage',
#       'mRID': '_0b1ca916-19d3-40e6-8212-4dfc108cc486',
#       'ConductingEquipment_mRID': '_8E85621E-5F77-449D-A851-245279A5AE9E',
#       'Terminal_mRID': '_02B27785-269A-42C3-AD05-A37F857AB005',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx226193134c0',
#       'ConnectivityNode': 'x2895449c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx227902981a0_Voltage',
#       'mRID': '_0b22622b-bfad-4221-b487-65bd6cab47d2',
#       'ConductingEquipment_mRID': '_5F22D438-0A32-4CAF-AF3E-07EB94A9B74A',
#       'Terminal_mRID': '_F548C9BC-301E-49E1-8ECE-31FC4DF64737',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx227902981a0',
#       'ConnectivityNode': 'x3047058a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5562928-1_Voltage',
#       'mRID': '_0b240957-3141-4483-83a7-df6deba02f98',
#       'ConductingEquipment_mRID': '_681DDF69-7934-44C2-9ED6-E31E55B5583C',
#       'Terminal_mRID': '_C092B647-74A3-4D7E-8407-3BACFD5F80EE',
#       'measurementType': 'PNV',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5562928-1',
#       'ConnectivityNode': 'm1047447',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx339016b0_Power',
#       'mRID': '_0b2515b8-5617-40d6-b2c8-55c1bb960039',
#       'ConductingEquipment_mRID': '_4998BC57-56A1-4323-9861-E74FB4562302',
#       'Terminal_mRID': '_3140DCF6-6F29-4A14-B124-49062F050A62',
#       'measurementType': 'VA',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx339016b0',
#       'ConnectivityNode': 'x3235273b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5957413-1_Power',
#       'mRID': '_0b2675a4-145f-46ae-b3d1-347c8b5f9742',
#       'ConductingEquipment_mRID': '_FE46AD7E-94A1-414A-A345-CF72353630AD',
#       'Terminal_mRID': '_584C4770-558B-49DC-8906-E88353BFFD6E',
#       'measurementType': 'VA',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5957413-1',
#       'ConnectivityNode': 'm1125979',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx21380599a0_Voltage',
#       'mRID': '_0b2b6d80-04ba-401d-be70-adfb6af89569',
#       'ConductingEquipment_mRID': '_A1CD2CD8-5EAB-47A2-A123-37803EF55050',
#       'Terminal_mRID': '_69510550-2CF5-45F7-AE72-0085EF130506',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx21380599a0',
#       'ConnectivityNode': 'x3066804a',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_339097b0',
#       'mRID': '_0b3232d2-e889-4a75-ac7a-85ebb2b476d2',
#       'ConductingEquipment_mRID': '_A760C73D-0071-441E-855C-09EF64BFFF06',
#       'Terminal_mRID': '_71290D49-9BE2-4283-9D32-C246B828F0AF',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '339097b0',
#       'ConnectivityNode': 'sx3085410b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6132680-1_Power',
#       'mRID': '_0b359c4e-e857-40b2-9684-57f7a73106ba',
#       'ConductingEquipment_mRID': '_B98D0B05-47A9-4A1E-8CDC-EC07FAB78A9F',
#       'Terminal_mRID': '_582A9E3F-FF30-456A-8AC4-37D74E04EF06',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6132680-1',
#       'ConnectivityNode': 'm1047713',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_226193745b0',
#       'mRID': '_0b39f0a2-e281-4d56-8152-ed4073a36d85',
#       'ConductingEquipment_mRID': '_D3988D95-3185-4831-AA59-4C36111DBE97',
#       'Terminal_mRID': '_A8142F4F-E406-4E43-94FD-3A3EAF2174AD',
#       'measurementType': 'VA',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '226193745b0',
#       'ConnectivityNode': 'sx2876798b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx338942a0_Voltage',
#       'mRID': '_0b3e2b51-bdb8-4598-8e6b-9cc125fd95cd',
#       'ConductingEquipment_mRID': '_53496CAB-84D7-4C3A-8B28-242EA13721DE',
#       'Terminal_mRID': '_76140B3E-EE1E-4BB6-97A5-BEA01D05CBB5',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx338942a0',
#       'ConnectivityNode': 'x2822869a',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_355944b0',
#       'mRID': '_0b433d90-3b2c-4629-b52b-dfc0ef2fa926',
#       'ConductingEquipment_mRID': '_4DE117FF-5A5C-400E-90BA-C6484814DB57',
#       'Terminal_mRID': '_D8A684CB-50BA-4D6D-9896-C8A2F4016B66',
#       'measurementType': 'VA',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '355944b0',
#       'ConnectivityNode': 'sx3197646b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5604685-1_Voltage',
#       'mRID': '_0b486001-ef34-495e-9d94-69cad97147a0',
#       'ConductingEquipment_mRID': '_D4CF8AA0-8914-40AB-961F-D62F2CE26D18',
#       'Terminal_mRID': '_E184A363-DF83-42DE-BD9C-A214F4072F85',
#       'measurementType': 'PNV',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5604685-1',
#       'ConnectivityNode': 'm1089145',
#       'SimObject': 'null'},
#      {'name': 'PowerElectronicsConnection_PhotovoltaicUnit_pv_1105',
#       'mRID': '_0b4d0847-6783-4d73-ad69-68067a2723fe',
#       'ConductingEquipment_mRID': '_1E5729A7-0F1B-4FE7-B6C4-E2A8D407CC8F',
#       'Terminal_mRID': '_612FF54D-6471-4365-8A2F-9636226C96EB',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'PowerElectronicsConnection',
#       'ConductingEquipment_name': 'pv_1105',
#       'ConnectivityNode': 'sx2785513a',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_356009a0',
#       'mRID': '_0b505654-4fd3-4ab7-8083-88ba4ed31f38',
#       'ConductingEquipment_mRID': '_E6B4F458-534D-41A4-8BA3-9E17D42BC8BE',
#       'Terminal_mRID': '_6991E235-BC67-4DBD-B4F8-33798974225A',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '356009a0',
#       'ConnectivityNode': 'sx2691936a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5487004-6_Power',
#       'mRID': '_0b536bee-9006-4ac6-8848-ced93c5e6717',
#       'ConductingEquipment_mRID': '_7EF1287C-8AF2-4CFE-9584-38585FE1C34B',
#       'Terminal_mRID': '_8F6AE337-E6EE-4F39-BE97-17D2DF5E24EA',
#       'measurementType': 'VA',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5487004-6',
#       'ConnectivityNode': 'm1026834',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6350577-1_Power',
#       'mRID': '_0b5481cd-f7b0-4c8d-aeca-e858f277ddbf',
#       'ConductingEquipment_mRID': '_46AE8BB5-4A4A-4F12-A1C3-208BC5818825',
#       'Terminal_mRID': '_48E09AF3-D5C0-4789-AD08-D7AE53DE79C0',
#       'measurementType': 'VA',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6350577-1',
#       'ConnectivityNode': 'l2673346',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_226194002b0',
#       'mRID': '_0b5caea2-04a8-49b9-8f31-dce9bfb84796',
#       'ConductingEquipment_mRID': '_E15B9D8A-64B9-44E7-B759-4EDECE195666',
#       'Terminal_mRID': '_F65DE63D-8514-42CE-9252-765AD7933099',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '226194002b0',
#       'ConnectivityNode': 'sx2801902b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5654470-1_Voltage',
#       'mRID': '_0b61a0d9-0f34-43bf-9ba0-45d36d662d69',
#       'ConductingEquipment_mRID': '_59C622E8-9BAB-42A3-803F-3E2F325E2C3B',
#       'Terminal_mRID': '_1ACCEBAF-888B-4AB3-9117-28DF7FEF05D5',
#       'measurementType': 'PNV',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5654470-1',
#       'ConnectivityNode': 'm1142826',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx321887c0_Power',
#       'mRID': '_0b657b93-914d-4ad5-9c55-d1dd7549e4fb',
#       'ConductingEquipment_mRID': '_34A233E9-414A-47F7-98FB-35A54101509B',
#       'Terminal_mRID': '_116CAF80-1FA1-44B7-86DF-8B32D50AD31D',
#       'measurementType': 'VA',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx321887c0',
#       'ConnectivityNode': 'x2691941c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5774462-2_Power',
#       'mRID': '_0b6b0172-cdda-4e1f-b300-f011ec695d2c',
#       'ConductingEquipment_mRID': '_E6E4D3AB-FB95-4F28-857C-6CE1320B0F5C',
#       'Terminal_mRID': '_45D38654-50D7-4A1B-9A04-8247298AC708',
#       'measurementType': 'VA',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5774462-2',
#       'ConnectivityNode': 'm3036165',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5865249-1_Power',
#       'mRID': '_0b6b4d83-4535-4e00-a7a3-2386a9c3349a',
#       'ConductingEquipment_mRID': '_91AA020D-2E29-41AB-99F0-1FD0DD4FF842',
#       'Terminal_mRID': '_7A693119-C660-4071-AAE0-492E84BE3880',
#       'measurementType': 'VA',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5865249-1',
#       'ConnectivityNode': 'm1026697',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx21389307c0_Voltage',
#       'mRID': '_0b6c447c-4cc0-45dc-b540-586e0d470606',
#       'ConductingEquipment_mRID': '_4607D96B-12A4-4682-83FD-B0C49CD6F377',
#       'Terminal_mRID': '_D9FE3A87-EAD4-4533-9410-C2AFE2B4DBA7',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx21389307c0',
#       'ConnectivityNode': 'x2692655c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx226192493b0_Voltage',
#       'mRID': '_0b6ce06c-a068-4b81-abc5-fd89304d85b8',
#       'ConductingEquipment_mRID': '_03731937-2791-4688-A738-EFFF20A265C5',
#       'Terminal_mRID': '_F6BDA1C0-2B30-4B38-BC6D-3A6D44CDB599',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx226192493b0',
#       'ConnectivityNode': 'sx2764399b',
#       'SimObject': 'null'},
#      ...]}]},
#  'responseComplete': True,
#  'id': '1548490521'}

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 4.2. Query for CIM Feeder Index
#
# This API call returns a python dictionary of the available feeders in the Blazegraph database of power system models.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "CIM Feeder Index"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "CIM Feeder Index",
    "parameters":{"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ---
# # 5. Querying for OpenDSS Configuration Files
#
# ## 5.1. Query for all OpenDSS Files
#
# This API call generates all the OpenDSS files necessary to solve the power system model in OpenDSS. The query returns a directory where the set of DSS files are located.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "DSS All"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                 "directory":                          desired output directory as string ,
#                 "simulation_name":                     string ,
#                 "simulation_start_time":              epoch time number ,
#                 "simulation_duration":                number ,
#                 "simulation_id":                      number ,
#                 "simulation_broker_host":             string ,
#                 "simulation_broker_port":             number ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string ,
#                 "solver_method":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.
#
# __Example: Export IEEE 13 node model with constant current loads to DSS files :__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS All",
    "parameters": {
        "directory": "/tmp/dsssimulation/",
        "model_id": model_mrid,
        "simulation_id": "12345678",
        "simulation_name": "ieee13",
        "simulation_start_time": "1518958800",
        "simulation_duration": "60",
        "simulation_broker_host": "localhost",
        "simulation_broker_port": "61616",
        "schedule_name": "ieeezipload",
        "load_scaling_factor": "1.0",
        "z_fraction": "0.0",
        "i_fraction": "1.0",
        "p_fraction": "0.0",
        "solver_method": "NR" }
}

gapps.get_response(topic, message)

# %% [markdown]
# __Note:__ The output directory is inside the GridAPPS-D Docker Container, not in your Ubuntu or Windows environment. To access the files, it is necessary to change directories to those inside the docker container.
#
# Open a new Ubuntu terminal and run:
# * `docker exec -it gridappsd-docker_gridappsd_1 bash`
# * `cd /tmp/dssdsimulation`
# * `ls -l`
#
# To copy the files to your regular directory, see Lesson 0.XX (to be released shortly) on working with Docker containers.

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 5.2. Query for OpenDSS Base File
#
# This API call generates a single DSS file that contains the entire power system model that can be solved in OpenDSS. The query returns the entire model DSS file wrapped in a python dictionary.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "DSS Base"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.

# %% [markdown]
# __Example 1: Create GLM base file using nominal load values:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS Base",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message)
# Out:
# {'error': 'Invalid json returned',
#  'header': {'content-length': '8445',
#   'expires': '0',
#   'destination': '/temp-queue/response.20210307Mar0252',
#   'GOSS_SUBJECT': 'system',
#   'subscription': '594154',
#   'priority': '4',
#   'transformation': 'TEXT',
#   'GOSS_HAS_SUBJECT': 'true',
#   'message-id': 'ID:b7d4feec7581-37015-1614216594584-4:9:-1:1:19',
#   'persistent': 'true',
#   'timestamp': '1615086173663'},
#  'message': '{"data":clear\nnew Circuit.source phases=3 bus1=sourcebus basekv=115.000 pu=1.00000 angle=30.00000 r0=0.17960 x0=0.53881 r1=0.16038 x1=0.64151\n\n\n\n\n\nnew Linecode.mtx605 nphases=1 units=mi rmatrix=[1.32924 ] xmatrix=[1.34754 ] cmatrix=[0.00000 ]\nnew Linecode.mtx606 nphases=3 units=mi rmatrix=[0.791743 | 0.318485 0.781670 | 0.283458 0.318485 0.791743 ] xmatrix=[0.438364 | 0.0276846 0.396708 | -0.0184209 0.0276846 0.438364 ] cmatrix=[383.949 | 0.00000 383.949 | 0.00000 0.00000 383.949 ]\nnew Linecode.mtx603 nphases=2 units=mi rmatrix=[1.32384 | 0.206606 1.32944 ] xmatrix=[1.35694 | 0.459113 1.34714 ] cmatrix=[0.00000 | 0.00000 0.00000 ]\nnew Linecode.mtx604 nphases=2 units=mi rmatrix=[1.32384 | 0.206606 1.32944 ] xmatrix=[1.35694 | 0.459113 1.34714 ] cmatrix=[0.00000 | 0.00000 0.00000 ]\nnew Linecode.mtx607 nphases=1 units=mi rmatrix=[1.34254 ] xmatrix=[0.512414 ] cmatrix=[236.001 ]\nnew Linecode.mtx601 nphases=3 units=mi rmatrix=[0.346509 | 0.153504 0.337509 | 0.158004 0.156004 0.341409 ] xmatrix=[1.01793 | 0.384911 1.04783 | 0.423612 0.501714 1.03483 ] cmatrix=[0.00000 | 0.00000 0.00000 | 0.00000 0.00000 0.00000 ]\nnew Linecode.mtx602 nphases=3 units=mi rmatrix=[0.752621 | 0.153504 0.747520 | 0.156004 0.158004 0.743620 ] xmatrix=[1.18143 | 0.384911 1.19833 | 0.501714 0.423612 1.21123 ] cmatrix=[0.00000 | 0.00000 0.00000 | 0.00000 0.00000 0.00000 ]\n\n\nnew Xfmrcode.ct5 windings=3 phases=1 xhl=2.040000 xht=2.040000 xlt=1.360000 %imag=0.500 %noloadloss=0.000\n~ wdg=1 conn=w kv=2.400 kva=5.0 %r=0.600000\n~ wdg=2 conn=w kv=0.120 kva=5.0 %r=1.200000\n~ wdg=3 conn=w kv=0.120 kva=5.0 %r=1.200000\nnew Xfmrcode.cimxfmrcode_reg3 windings=2 phases=1 xhl=0.010000 %imag=0.000 %noloadloss=0.000\n~ wdg=1 conn=w kv=2.400 kva=1666.0 %r=0.005000\n~ wdg=2 conn=w kv=2.400 kva=1666.0 %r=0.005000\nnew Xfmrcode.cimxfmrcode_reg2 windings=2 phases=1 xhl=0.010000 %imag=0.000 %noloadloss=0.000\n~ wdg=1 conn=w kv=2.400 kva=1666.0 %r=0.005000\n~ wdg=2 conn=w kv=2.400 kva=1666.0 %r=0.005000\nnew Xfmrcode.cimxfmrcode_reg1 windings=2 phases=1 xhl=0.010000 %imag=0.000 %noloadloss=0.000\n~ wdg=1 conn=w kv=2.400 kva=1666.0 %r=0.005000\n~ wdg=2 conn=w kv=2.400 kva=1666.0 %r=0.005000\n\nnew PVSystem.school phases=3 bus1=634.1.2.3 conn=w kva=300.000 kv=0.480 pmpp=300.000 irrad=0.800 pf=1.0000 vminpu=0.9000 LimitCurrent=yes\nnew PVSystem.house phases=2 bus1=house.2.1 conn=w kva=5.000 kv=0.208 pmpp=5.000 irrad=0.800 pf=1.0000 vminpu=0.9000 LimitCurrent=yes\n\nnew Storage.school phases=3 bus1=634.1.2.3 conn=w kva=100.000 kv=0.480 kwhrated=200.000 kwhstored=100.000 state=charging vminpu=0.9000 LimitCurrent=yes kw=-100.00\nnew Storage.house phases=2 bus1=house.1.2 conn=w kva=5.000 kv=0.208 kwhrated=13.500 kwhstored=5.000 state=charging vminpu=0.9000 LimitCurrent=yes kw=-5.00\n\n\nnew Load.670b phases=1 bus1=670.2 conn=w kw=66.000 kvar=38.000 numcust=1 kv=2.402 model=1\nnew Load.670a phases=1 bus1=670.1 conn=w kw=17.000 kvar=10.000 numcust=1 kv=2.402 model=1\nnew Load.670c phases=1 bus1=670.3 conn=w kw=117.000 kvar=68.000 numcust=1 kv=2.402 model=1\nnew Load.house phases=2 bus1=house.2.1 conn=w kw=5.000 kvar=3.099 numcust=1 kv=0.208 model=1\nnew Load.692 phases=1 bus1=692.3.1 conn=d kw=170.000 kvar=151.000 numcust=1 kv=4.160 model=5\nnew Load.671 phases=3 bus1=671.1.2.3 conn=d kw=1155.000 kvar=660.000 numcust=1 kv=4.160 model=1\nnew Load.634b phases=1 bus1=634.2 conn=w kw=120.000 kvar=90.000 numcust=1 kv=0.277 model=1\nnew Load.634a phases=1 bus1=634.1 conn=w kw=160.000 kvar=110.000 numcust=1 kv=0.277 model=1\nnew Load.652 phases=1 bus1=652.1 conn=w kw=128.000 kvar=86.000 numcust=1 kv=2.402 model=2\nnew Load.675a phases=1 bus1=675.1 conn=w kw=485.000 kvar=190.000 numcust=1 kv=2.402 model=1\nnew Load.634c phases=1 bus1=634.3 conn=w kw=120.000 kvar=90.000 numcust=1 kv=0.277 model=1\nnew Load.611 phases=1 bus1=611.3 conn=w kw=170.000 kvar=80.000 numcust=1 kv=2.402 model=5\nnew Load.675c phases=1 bus1=675.3 conn=w kw=290.000 kvar=212.000 numcust=1 kv=2.402 ...

# %% [markdown]
# __Example 2: Create GLM base file using all constant current loads and hourly load curve:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS Base",
    "parameters": {
        "model_id": model_mrid,
        "load_scaling_factor": "1.0",
        "z_fraction": 0.0,
        "i_fraction": 1.0,
        "p_fraction": "0.0",
        "schedule_name": "ieeezipload"}
}

gapps.get_response(topic, message)

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 5.3. Query for OpenDSS Coordinate File
#
# This API call generates a file with all the XY coordinates used by OpenDSS when plotting the feeder.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "DSS Coordinate"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS Coordinate",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message)
# Out:
# {'error': 'Invalid json returned',
#  'header': {'content-length': '429',
#   'expires': '0',
#   'destination': '/temp-queue/response.20210307Mar4757',
#   'GOSS_SUBJECT': 'system',
#   'subscription': '838517',
#   'priority': '4',
#   'transformation': 'TEXT',
#   'GOSS_HAS_SUBJECT': 'true',
#   'message-id': 'ID:b7d4feec7581-37015-1614216594584-4:9:-1:1:20',
#   'persistent': 'true',
#   'timestamp': '1615088878603'},
#  'message': '{"data":// bus locations - after\nsourcebus,200.0,400.0\nxf1,390.0,250.0\ntap,95.0,100.0\nmid,200.0,245.0\nhouse,200.0,190.0\n680,200.0,0.0\n670,200.0,200.0\n692,250.0,100.0\n650z,205.0,350.0\n671,200.0,100.0\n650,200.0,350.0\n684,100.0,100.0\n652,100.0,0.0\n675,400.0,100.0\n632,200.0,250.0\n611,0.0,100.0\n633,350.0,250.0\n645,100.0,250.0\n634,400.0,250.0\n646,0.0,250.0\nbrkr,200.0,325.0\nrg60,200.0,300.0\n,"responseComplete":true,"id":"872292537"}'}

# %% [markdown]
# [Return to Top](#Table-of-Contents)

# %% [markdown]
# ## 5.4. Query for Y-Bus Matrix
#
# This API call generates a Y-Bus matrix from __either__ the model mRID or the simulation id.
#
# __Note:__ The GridAPPS-D platform currently does not have an in-built topology processor, so the Y-Bus matrix is NOT updated during the simulation to reflect switching actions or transformer tap changes that happen in real time.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "YBus Export"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OR
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %% [markdown]
# __Example 1: Request Y-Bus for IEEE 13 node model using model mRID:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "YBus Export",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# __Example 2: Request Y-Bus for IEEE 13 node model with all loads set as constant current using model mRID:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "YBus Export",
    "parameters": {
        "model_id": "_C1C3E687-6FFD-C753-582B-632A27E28507",
        "load_scaling_factor": "2.0",
        "schedule_name": "ieeezipload",
        "z_fraction": "0.4",
        "i_fraction": "0.3",
        "p_fraction": "0.3" }
}

gapps.get_response(topic, message)

# %% [markdown]
# __Example 3: Obtain Y-Bus from simulation_id:__

# %%
viz_simulation_id = "paste id here"

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType":"YBus Export",
    "parameters":{"simulation_id": viz_simulation_id}
}

gapps.get_response(topic, message)

# %% [markdown]
# [Return to Top](#Table-of-Contents)
